# %% [markdown]
# FINAL MAINS

# %%
# main.py

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s: %(message)s')
import sys
import os
sys.path.insert(0, os.path.abspath('.'))

from fx_loader import load_fx_rates
from cores.pipeline import run_pipeline
from exchanges.kgi import EXCHANGE_CONFIG as KGI_CONFIG, step_transform as kgi_transform, step_load as kgi_load
from exchanges.itau import EXCHANGE_CONFIG as ITAU_CONFIG, step_transform as itau_transform, step_load as itau_load


START = "20260101"
END   = "20260331"

# 1. Load FX rates first
load_fx_rates(START, END)

# 2. Run KGI
run_pipeline(
    config=KGI_CONFIG,
    transform_func=kgi_transform,
    load_func=kgi_load,
    credentials_file="aws_credentials.json",
    start_date_str=START,
    end_date_str=END
)

# 3. Run Itau
run_pipeline(
    config=ITAU_CONFIG,
    transform_func=itau_transform,
    load_func=itau_load,
    credentials_file="aws_credentials.json",
    start_date_str=START,
    end_date_str=END
)
# Out:
# 2026-04-13 18:28:12,125 INFO:
# ============================================================
# 2026-04-13 18:28:12,126 INFO: Starting FX Rate Load Process
# 2026-04-13 18:28:12,126 INFO: ============================================================
# 2026-04-13 18:28:12,138 INFO:   ✓ Skipping (already loaded): 2026-01-01
# 2026-04-13 18:28:12,143 INFO:   ✓ Skipping (already loaded): 2026-01-02
# 2026-04-13 18:28:12,146 INFO:   ✓ Skipping (already loaded): 2026-01-05
# 2026-04-13 18:28:12,150 INFO:   ✓ Skipping (already loaded): 2026-01-06
# 2026-04-13 18:28:12,154 INFO:   ✓ Skipping (already loaded): 2026-01-07
# 2026-04-13 18:28:12,157 INFO:   ✓ Skipping (already loaded): 2026-01-08
# 2026-04-13 18:28:12,161 INFO:   ✓ Skipping (already loaded): 2026-01-09
# 2026-04-13 18:28:12,164 INFO:   ✓ Skipping (already loaded): 2026-01-12
# 2026-04-13 18:28:12,168 INFO:   ✓ Skipping (already loaded): 2026-01-13
# 2026-04-13 18:28:12,171 INFO:   ✓ Skipping (already loaded): 2026-01-14
# 2026-04-13 18:28:12,174 INFO:   ✓ Skipping (already loaded): 2026-01-15
# 2026-04-13 18:28:12,177 INFO:   ✓ Skipping (already loaded): 2026-01-16
# 2026-04-13 18:28:12,180 INFO:   ✓ Skipping (already loaded): 2026-01-19
# 2026-04-13 18:28:12,184 INFO:   ✓ Skipping (already loaded): 2026-01-20
# 2026-04-13 18:28:12,188 INFO:   ✓ Skipping (already loaded): 2026-01-21
# 2026-04-13 18:28:12,191 INFO:   ✓ Skipping (already loaded): 2026-01-22
# 2026-04-13 18:28:12,194 INFO:   ✓ Skipping (already loaded): 2026-01-23
# 2026-04-13 18:28:12,197 INFO:   ✓ Skipping (already loaded): 2026-01-26
# 2026-04-13 18:28:12,201 INFO:   ✓ Skipping (already loaded): 2026-01-27
# 2026-04-13 18:28:12,205 INFO:   ✓ Skipping (already loaded): 2026-01-28
# 2026-04-13 18:28:12,208 INFO:   ✓ Skipping (already loaded): 2026-01-29
# 2026-04-13 18:28:12,212 INFO:   ✓ Skipping (already loaded): 2026-01-30
# 2026-04-13 18:28:12,218 INFO:   ✓ Skipping (already loaded): 2026-02-02
# 2026-04-13 18:28:12,224 INFO:   ✓ Skipping (already loaded): 2026-02-03
# 2026-04-13 18:28:12,232 INFO:   ✓ Skipping (already loaded): 2026-02-04
# 2026-04-13 18:28:12,236 INFO:   ✓ Skipping (already loaded): 2026-02-05
# 2026-04-13 18:28:12,242 INFO:   ✓ Skipping (already loaded): 2026-02-06
# 2026-04-13 18:28:12,246 INFO:   ✓ Skipping (already loaded): 2026-02-09
# 2026-04-13 18:28:12,250 INFO:   ✓ Skipping (already loaded): 2026-02-10
# 2026-04-13 18:28:12,255 INFO:   ✓ Skipping (already loaded): 2026-02-11
# 2026-04-13 18:28:12,259 INFO:   ✓ Skipping (already loaded): 2026-02-12
# 2026-04-13 18:28:12,262 INFO:   ✓ Skipping (already loaded): 2026-02-13
# 2026-04-13 18:28:12,266 INFO:   ✓ Skipping (already loaded): 2026-02-16
# 2026-04-13 18:28:12,271 INFO:   ✓ Skipping (already loaded): 2026-02-17
# 2026-04-13 18:28:12,275 INFO:   ✓ Skipping (already loaded): 2026-02-18
# 2026-04-13 18:28:12,278 INFO:   ✓ Skipping (already loaded): 2026-02-19
# 2026-04-13 18:28:12,282 INFO:   ✓ Skipping (already loaded): 2026-02-20
# 2026-04-13 18:28:12,286 INFO:   ✓ Skipping (already loaded): 2026-02-23
# 2026-04-13 18:28:12,290 INFO:   ✓ Skipping (already loaded): 2026-02-24
# 2026-04-13 18:28:12,293 INFO:   ✓ Skipping (already loaded): 2026-02-25
# 2026-04-13 18:28:12,297 INFO:   ✓ Skipping (already loaded): 2026-02-26
# 2026-04-13 18:28:12,301 INFO:   ✓ Skipping (already loaded): 2026-02-27
# 2026-04-13 18:28:12,305 INFO:   ✓ Skipping (already loaded): 2026-03-02
# 2026-04-13 18:28:12,309 INFO:   ✓ Skipping (already loaded): 2026-03-03
# 2026-04-13 18:28:12,312 INFO:   ✓ Skipping (already loaded): 2026-03-04
# 2026-04-13 18:28:12,316 INFO:   ✓ Skipping (already loaded): 2026-03-05
# 2026-04-13 18:28:12,320 INFO:   ✓ Skipping (already loaded): 2026-03-06
# 2026-04-13 18:28:12,323 INFO:   ✓ Skipping (already loaded): 2026-03-09
# 2026-04-13 18:28:12,327 INFO:   ✓ Skipping (already loaded): 2026-03-10
# 2026-04-13 18:28:12,330 INFO:   ✓ Skipping (already loaded): 2026-03-11
# 2026-04-13 18:28:12,334 INFO:   ✓ Skipping (already loaded): 2026-03-12
# 2026-04-13 18:28:12,338 INFO:   ✓ Skipping (already loaded): 2026-03-13
# 2026-04-13 18:28:12,342 INFO:   ✓ Skipping (already loaded): 2026-03-16
# 2026-04-13 18:28:12,346 INFO:   ✓ Skipping (already loaded): 2026-03-17
# 2026-04-13 18:28:12,350 INFO:   ✓ Skipping (already loaded): 2026-03-18
# 2026-04-13 18:28:12,354 INFO:   ✓ Skipping (already loaded): 2026-03-19
# 2026-04-13 18:28:12,358 INFO:   ✓ Skipping (already loaded): 2026-03-20
# 2026-04-13 18:28:12,361 INFO:   ✓ Skipping (already loaded): 2026-03-23
# 2026-04-13 18:28:12,365 INFO:   ✓ Skipping (already loaded): 2026-03-24
# 2026-04-13 18:28:12,368 INFO:   ✓ Skipping (already loaded): 2026-03-25
# 2026-04-13 18:28:12,372 INFO:   ✓ Skipping (already loaded): 2026-03-26
# 2026-04-13 18:28:12,375 INFO:   ✓ Skipping (already loaded): 2026-03-27
# 2026-04-13 18:28:12,379 INFO:   ✓ Skipping (already loaded): 2026-03-30
# 2026-04-13 18:28:12,386 INFO:   ✓ Skipping (already loaded): 2026-03-31
# 2026-04-13 18:28:12,387 INFO:
# ============================================================
# 2026-04-13 18:28:12,387 INFO: FX Rate Load Process Completed
# 2026-04-13 18:28:12,387 INFO: ============================================================
#
# 2026-04-13 18:28:12,388 INFO:
# ============================================================
# 2026-04-13 18:28:12,388 INFO: STEP 1: DOWNLOAD  [KGI]
# 2026-04-13 18:28:12,388 INFO: ============================================================
# 2026-04-13 18:28:12,457 INFO:    ✓ Already downloaded, queued for load: KT513_20260101_NT.csv
# 2026-04-13 18:28:12,461 INFO:    ✓ Already downloaded, queued for load: KT513_20260102_NT.csv
# 2026-04-13 18:28:12,465 INFO:    ✓ Already downloaded, queued for load: KT513_20260105_NT.csv
# 2026-04-13 18:28:12,469 INFO:    ✓ Already downloaded, queued for load: KT513_20260106_NT.csv
# 2026-04-13 18:28:12,473 INFO:    ✓ Already downloaded, queued for load: KT513_20260107_NT.csv
# 2026-04-13 18:28:12,476 INFO:    ✓ Already downloaded, queued for load: KT513_20260108_NT.csv
# 2026-04-13 18:28:12,480 INFO:    ✓ Already downloaded, queued for load: KT513_20260109_NT.csv
# 2026-04-13 18:28:12,484 INFO:    ✓ Already downloaded, queued for load: KT513_20260112_NT.csv
# 2026-04-13 18:28:12,488 INFO:    ✓ Already downloaded, queued for load: KT513_20260113_NT.csv
# 2026-04-13 18:28:12,491 INFO:    ✓ Already downloaded, queued for load: KT513_20260114_NT.csv
# 2026-04-13 18:28:12,494 INFO:    ✓ Already downloaded, queued for load: KT513_20260115_NT.csv
# 2026-04-13 18:28:12,497 INFO:    ✓ Already downloaded, queued for load: KT513_20260116_NT.csv
# 2026-04-13 18:28:12,501 INFO:    ✓ Already downloaded, queued for load: KT513_20260119_NT.csv
# 2026-04-13 18:28:12,506 INFO:    ✓ Already downloaded, queued for load: KT513_20260120_NT.csv
# 2026-04-13 18:28:12,509 INFO:    ✓ Already downloaded, queued for load: KT513_20260121_NT.csv
# 2026-04-13 18:28:12,513 INFO:    ✓ Already downloaded, queued for load: KT513_20260122_NT.csv
# 2026-04-13 18:28:12,519 INFO:    ✓ Already downloaded, queued for load: KT513_20260123_NT.csv
# 2026-04-13 18:28:12,523 INFO:    ✓ Already downloaded, queued for load: KT513_20260126_NT.csv
# 2026-04-13 18:28:12,527 INFO:    ✓ Already downloaded, queued for load: KT513_20260127_NT.csv
# 2026-04-13 18:28:12,530 INFO:    ✓ Already downloaded, queued for load: KT513_20260128_NT.csv
# 2026-04-13 18:28:12,534 INFO:    ✓ Already downloaded, queued for load: KT513_20260129_NT.csv
# 2026-04-13 18:28:12,537 INFO:    ✓ Already downloaded, queued for load: KT513_20260130_NT.csv
# 2026-04-13 18:28:12,541 INFO:    ✓ Already downloaded, queued for load: KT513_20260202_NT.csv
# 2026-04-13 18:28:12,545 INFO:    ✓ Already downloaded, queued for load: KT513_20260203_NT.csv
# 2026-04-13 18:28:12,551 INFO:    ✓ Already downloaded, queued for load: KT513_20260204_NT.csv
# 2026-04-13 18:28:12,555 INFO:    ✓ Already downloaded, queued for load: KT513_20260205_NT.csv
# 2026-04-13 18:28:12,560 INFO:    ✓ Already downloaded, queued for load: KT513_20260206_NT.csv
# 2026-04-13 18:28:12,565 INFO:    ✓ Already downloaded, queued for load: KT513_20260209_NT.csv
# 2026-04-13 18:28:12,568 INFO:    ✓ Already downloaded, queued for load: KT513_20260210_NT.csv
# 2026-04-13 18:28:12,572 INFO:    ✓ Already downloaded, queued for load: KT513_20260211_NT.csv
# 2026-04-13 18:28:12,576 INFO:    ✓ Already downloaded, queued for load: KT513_20260212_NT.csv
# 2026-04-13 18:28:12,581 INFO:    ✓ Already downloaded, queued for load: KT513_20260213_NT.csv
# 2026-04-13 18:28:12,585 INFO:    ✓ Already downloaded, queued for load: KT513_20260216_NT.csv
# 2026-04-13 18:28:12,590 INFO:    ✓ Already downloaded, queued for load: KT513_20260217_NT.csv
# 2026-04-13 18:28:12,595 INFO:    ✓ Already downloaded, queued for load: KT513_20260218_NT.csv
# 2026-04-13 18:28:12,600 INFO:    ✓ Already downloaded, queued for load: KT513_20260219_NT.csv
# 2026-04-13 18:28:12,604 INFO:    ✓ Already downloaded, queued for load: KT513_20260220_NT.csv
# 2026-04-13 18:28:12,608 INFO:    ✓ Already downloaded, queued for load: KT513_20260223_NT.csv
# 2026-04-13 18:28:12,611 INFO:    ✓ Already downloaded, queued for load: KT513_20260224_NT.csv
# 2026-04-13 18:28:12,615 INFO:    ✓ Already downloaded, queued for load: KT513_20260225_NT.csv
# 2026-04-13 18:28:12,619 INFO:    ✓ Already downloaded, queued for load: KT513_20260226_NT.csv
# 2026-04-13 18:28:12,622 INFO:    ✓ Already downloaded, queued for load: KT513_20260227_NT.csv
# 2026-04-13 18:28:12,626 INFO:    ✓ Already downloaded, queued for load: KT513_20260302_NT.csv
# 2026-04-13 18:28:12,629 INFO:    ✓ Already downloaded, queued for load: KT513_20260303_NT.csv
# 2026-04-13 18:28:12,634 INFO:    ✓ Already downloaded, queued for load: KT513_20260304_NT.csv
# 2026-04-13 18:28:12,637 INFO:    ✓ Already downloaded, queued for load: KT513_20260305_NT.csv
# 2026-04-13 18:28:12,642 INFO:    ✓ Already downloaded, queued for load: KT513_20260306_NT.csv
# 2026-04-13 18:28:12,648 INFO:    ✓ Already downloaded, queued for load: KT513_20260309_NT.csv
# 2026-04-13 18:28:12,653 INFO:    ✓ Already downloaded, queued for load: KT513_20260310_NT.csv
# 2026-04-13 18:28:12,659 INFO:    ✓ Already downloaded, queued for load: KT513_20260311_NT.csv
# 2026-04-13 18:28:12,665 INFO:    ✓ Already downloaded, queued for load: KT513_20260312_NT.csv
# 2026-04-13 18:28:12,670 INFO:    ✓ Already downloaded, queued for load: KT513_20260313_NT.csv
# 2026-04-13 18:28:12,677 INFO:    ✓ Already downloaded, queued for load: KT513_20260316_NT.csv
# 2026-04-13 18:28:12,681 INFO:    ✓ Already downloaded, queued for load: KT513_20260317_NT.csv
# 2026-04-13 18:28:12,685 INFO:    ✓ Already downloaded, queued for load: KT513_20260318_NT.csv
# 2026-04-13 18:28:12,689 INFO:    ✓ Already downloaded, queued for load: KT513_20260319_NT.csv
# 2026-04-13 18:28:12,694 INFO:    ✓ Already downloaded, queued for load: KT513_20260320_NT.csv
# 2026-04-13 18:28:12,697 INFO:    ✓ Already downloaded, queued for load: KT513_20260323_NT.csv
# 2026-04-13 18:28:12,701 INFO:    ✓ Already downloaded, queued for load: KT513_20260324_NT.csv
# 2026-04-13 18:28:12,706 INFO:    ✓ Already downloaded, queued for load: KT513_20260325_NT.csv
# 2026-04-13 18:28:12,713 INFO:    ✓ Already downloaded, queued for load: KT513_20260326_NT.csv
# 2026-04-13 18:28:12,717 INFO:    ✓ Already downloaded, queued for load: KT513_20260327_NT.csv
# 2026-04-13 18:28:12,720 INFO:    ✓ Already downloaded, queued for load: KT513_20260330_NT.csv
# 2026-04-13 18:28:12,725 INFO:    ✓ Already downloaded, queued for load: KT513_20260331_NT.csv
# 2026-04-13 18:28:12,725 INFO:
#    Total files ready for processing: 64
# 2026-04-13 18:28:12,725 INFO:
# ============================================================
# 2026-04-13 18:28:12,726 INFO: STEP 2 & 3: TRANSFORM + LOAD  [KGI]
# 2026-04-13 18:28:12,726 INFO: ============================================================
# 2026-04-13 18:28:12,726 INFO:
#   Processing: KT513_20260101_NT.csv
# 2026-04-13 18:28:12,732 INFO:
#   Processing: KT513_20260102_NT.csv
# 2026-04-13 18:28:12,762 INFO:   ✓ CommFeeUSD conversion complete for 2026-01-02
# 2026-04-13 18:28:12,764 INFO:
#   Processing: KT513_20260105_NT.csv
# 2026-04-13 18:28:12,793 INFO:   ✓ CommFeeUSD conversion complete for 2026-01-05
# 2026-04-13 18:28:12,794 INFO:
#   Processing: KT513_20260106_NT.csv
# 2026-04-13 18:28:12,822 INFO:   ✓ CommFeeUSD conversion complete for 2026-01-06
# 2026-04-13 18:28:12,824 INFO:
#   Processing: KT513_20260107_NT.csv
# 2026-04-13 18:28:12,854 INFO:   ✓ CommFeeUSD conversion complete for 2026-01-07
# 2026-04-13 18:28:12,856 INFO:
#   Processing: KT513_20260108_NT.csv
# 2026-04-13 18:28:12,887 INFO:   ✓ CommFeeUSD conversion complete for 2026-01-08
# 2026-04-13 18:28:12,889 INFO:
#   Processing: KT513_20260109_NT.csv
# 2026-04-13 18:28:12,920 INFO:   ✓ CommFeeUSD conversion complete for 2026-01-09
# 2026-04-13 18:28:12,922 INFO:
#   Processing: KT513_20260112_NT.csv
# 2026-04-13 18:28:12,951 INFO:   ✓ CommFeeUSD conversion complete for 2026-01-12
# 2026-04-13 18:28:12,954 INFO:
#   Processing: KT513_20260113_NT.csv
# 2026-04-13 18:28:12,986 INFO:   ✓ CommFeeUSD conversion complete for 2026-01-13
# 2026-04-13 18:28:12,988 INFO:
#   Processing: KT513_20260114_NT.csv
# 2026-04-13 18:28:13,021 INFO:   ✓ CommFeeUSD conversion complete for 2026-01-14
# 2026-04-13 18:28:13,022 INFO:
#   Processing: KT513_20260115_NT.csv
# 2026-04-13 18:28:13,057 INFO:   ✓ CommFeeUSD conversion complete for 2026-01
ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,002 INFO:
#   Processing: Axxela Report Full 20260309.csv
# 2026-04-13 18:28:17,024 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,024 INFO:
#   Processing: Axxela Report Full 20260310.csv
# 2026-04-13 18:28:17,044 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,045 INFO:
#   Processing: Axxela Report Full 20260311.csv
# 2026-04-13 18:28:17,063 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,063 INFO:
#   Processing: Axxela Report Full 20260312.csv
# 2026-04-13 18:28:17,088 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,089 INFO:
#   Processing: Axxela Report Full 20260313.csv
# 2026-04-13 18:28:17,110 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,110 INFO:
#   Processing: Axxela Report Full 20260316.csv
# 2026-04-13 18:28:17,131 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,131 INFO:
#   Processing: Axxela Report Full 20260317.csv
# 2026-04-13 18:28:17,155 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,155 INFO:
#   Processing: Axxela Report Full 20260318.csv
# 2026-04-13 18:28:17,181 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,182 INFO:
#   Processing: Axxela Report Full 20260319.csv
# 2026-04-13 18:28:17,207 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,207 INFO:
#   Processing: Axxela Report Full 20260320.csv
# 2026-04-13 18:28:17,240 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,240 INFO:
#   Processing: Axxela Report Full 20260323.csv
# 2026-04-13 18:28:17,270 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,270 INFO:
#   Processing: Axxela Report Full 20260324.csv
# 2026-04-13 18:28:17,296 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,297 INFO:
#   Processing: Axxela Report Full 20260325.csv
# 2026-04-13 18:28:17,321 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,321 INFO:
#   Processing: Axxela Report Full 20260326.csv
# 2026-04-13 18:28:17,351 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,351 INFO:
#   Processing: Axxela Report Full 20260327.csv
# 2026-04-13 18:28:17,376 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,376 INFO:
#   Processing: Axxela Report Full 20260330.csv
# 2026-04-13 18:28:17,395 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,395 INFO:
#   Processing: Axxela Report Full 20260331.csv
# 2026-04-13 18:28:17,418 ERROR: DB Error: 1364 (HY000): Field 'product_type' doesn't have a default value
# 2026-04-13 18:28:17,418 INFO:
# ============================================================
# 2026-04-13 18:28:17,419 INFO: PIPELINE COMPLETE  [Itau]
# 2026-04-13 18:28:17,419 INFO: ============================================================
# 2026-04-13 18:28:17,419 INFO:   Files downloaded : 60
# 2026-04-13 18:28:17,419 INFO:   Files loaded     : 0
# 2026-04-13 18:28:17,420 INFO:   Files skipped    : 0
# 2026-04-13 18:28:17,420 INFO:   Files failed     : 60
# 2026-04-13 18:28:17,420 INFO: ============================================================
# {'downloaded': 60, 'loaded': 0, 'skipped': 0, 'failed': 60}

# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s: %(message)s')

from cores.pipeline import run_pipeline
from exchanges.stonex import EXCHANGE_CONFIG, step_transform, step_load
from fx_loader import load_fx_rates

START = "20260101"
END   = "20260331"

# 1. Load FX rates first
load_fx_rates(START, END)

# 2. Then run StonEx
run_pipeline(
    config=EXCHANGE_CONFIG,
    transform_func=step_transform,
    load_func=step_load,
    credentials_file="aws_credentials.json",
    start_date_str=START,
    end_date_str=END
)
# Out:
# 2026-04-13 16:32:24,668 INFO:
# ============================================================
# 2026-04-13 16:32:24,669 INFO: Starting FX Rate Load Process
# 2026-04-13 16:32:24,669 INFO: ============================================================
# 2026-04-13 16:32:24,674 INFO:   ✓ Skipping (already loaded): 2026-01-01
# 2026-04-13 16:32:24,678 INFO:   ✓ Skipping (already loaded): 2026-01-02
# 2026-04-13 16:32:24,683 INFO:   ✓ Skipping (already loaded): 2026-01-05
# 2026-04-13 16:32:24,687 INFO:   ✓ Skipping (already loaded): 2026-01-06
# 2026-04-13 16:32:24,691 INFO:   ✓ Skipping (already loaded): 2026-01-07
# 2026-04-13 16:32:24,698 INFO:   ✓ Skipping (already loaded): 2026-01-08
# 2026-04-13 16:32:24,704 INFO:   ✓ Skipping (already loaded): 2026-01-09
# 2026-04-13 16:32:24,708 INFO:   ✓ Skipping (already loaded): 2026-01-12
# 2026-04-13 16:32:24,712 INFO:   ✓ Skipping (already loaded): 2026-01-13
# 2026-04-13 16:32:24,716 INFO:   ✓ Skipping (already loaded): 2026-01-14
# 2026-04-13 16:32:24,719 INFO:   ✓ Skipping (already loaded): 2026-01-15
# 2026-04-13 16:32:24,723 INFO:   ✓ Skipping (already loaded): 2026-01-16
# 2026-04-13 16:32:24,726 INFO:   ✓ Skipping (already loaded): 2026-01-19
# 2026-04-13 16:32:24,730 INFO:   ✓ Skipping (already loaded): 2026-01-20
# 2026-04-13 16:32:24,734 INFO:   ✓ Skipping (already loaded): 2026-01-21
# 2026-04-13 16:32:24,737 INFO:   ✓ Skipping (already loaded): 2026-01-22
# 2026-04-13 16:32:24,740 INFO:   ✓ Skipping (already loaded): 2026-01-23
# 2026-04-13 16:32:24,744 INFO:   ✓ Skipping (already loaded): 2026-01-26
# 2026-04-13 16:32:24,748 INFO:   ✓ Skipping (already loaded): 2026-01-27
# 2026-04-13 16:32:24,752 INFO:   ✓ Skipping (already loaded): 2026-01-28
# 2026-04-13 16:32:24,755 INFO:   ✓ Skipping (already loaded): 2026-01-29
# 2026-04-13 16:32:24,758 INFO:   ✓ Skipping (already loaded): 2026-01-30
# 2026-04-13 16:32:24,762 INFO:   ✓ Skipping (already loaded): 2026-02-02
# 2026-04-13 16:32:24,766 INFO:   ✓ Skipping (already loaded): 2026-02-03
# 2026-04-13 16:32:24,769 INFO:   ✓ Skipping (already loaded): 2026-02-04
# 2026-04-13 16:32:24,773 INFO:   ✓ Skipping (already loaded): 2026-02-05
# 2026-04-13 16:32:24,776 INFO:   ✓ Skipping (already loaded): 2026-02-06
# 2026-04-13 16:32:24,780 INFO:   ✓ Skipping (already loaded): 2026-02-09
# 2026-04-13 16:32:24,784 INFO:   ✓ Skipping (already loaded): 2026-02-10
# 2026-04-13 16:32:24,787 INFO:   ✓ Skipping (already loaded): 2026-02-11
# 2026-04-13 16:32:24,791 INFO:   ✓ Skipping (already loaded): 2026-02-12
# 2026-04-13 16:32:24,794 INFO:   ✓ Skipping (already loaded): 2026-02-13
# 2026-04-13 16:32:24,798 INFO:   ✓ Skipping (already loaded): 2026-02-16
# 2026-04-13 16:32:24,801 INFO:   ✓ Skipping (already loaded): 2026-02-17
# 2026-04-13 16:32:24,805 INFO:   ✓ Skipping (already loaded): 2026-02-18
# 2026-04-13 16:32:24,808 INFO:   ✓ Skipping (already loaded): 2026-02-19
# 2026-04-13 16:32:24,812 INFO:   ✓ Skipping (already loaded): 2026-02-20
# 2026-04-13 16:32:24,816 INFO:   ✓ Skipping (already loaded): 2026-02-23
# 2026-04-13 16:32:24,820 INFO:   ✓ Skipping (already loaded): 2026-02-24
# 2026-04-13 16:32:24,823 INFO:   ✓ Skipping (already loaded): 2026-02-25
# 2026-04-13 16:32:24,827 INFO:   ✓ Skipping (already loaded): 2026-02-26
# 2026-04-13 16:32:24,831 INFO:   ✓ Skipping (already loaded): 2026-02-27
# 2026-04-13 16:32:24,834 INFO:   ✓ Skipping (already loaded): 2026-03-02
# 2026-04-13 16:32:24,837 INFO:   ✓ Skipping (already loaded): 2026-03-03
# 2026-04-13 16:32:24,840 INFO:   ✓ Skipping (already loaded): 2026-03-04
# 2026-04-13 16:32:24,844 INFO:   ✓ Skipping (already loaded): 2026-03-05
# 2026-04-13 16:32:24,851 INFO:   ✓ Skipping (already loaded): 2026-03-06
# 2026-04-13 16:32:24,858 INFO:   ✓ Skipping (already loaded): 2026-03-09
# 2026-04-13 16:32:24,864 INFO:   ✓ Skipping (already loaded): 2026-03-10
# 2026-04-13 16:32:24,869 INFO:   ✓ Skipping (already loaded): 2026-03-11
# 2026-04-13 16:32:24,874 INFO:   ✓ Skipping (already loaded): 2026-03-12
# 2026-04-13 16:32:24,878 INFO:   ✓ Skipping (already loaded): 2026-03-13
# 2026-04-13 16:32:24,882 INFO:   ✓ Skipping (already loaded): 2026-03-16
# 2026-04-13 16:32:24,887 INFO:   ✓ Skipping (already loaded): 2026-03-17
# 2026-04-13 16:32:24,890 INFO:   ✓ Skipping (already loaded): 2026-03-18
# 2026-04-13 16:32:24,894 INFO:   ✓ Skipping (already loaded): 2026-03-19
# 2026-04-13 16:32:24,898 INFO:   ✓ Skipping (already loaded): 2026-03-20
# 2026-04-13 16:32:24,902 INFO:   ✓ Skipping (already loaded): 2026-03-23
# 2026-04-13 16:32:24,906 INFO:   ✓ Skipping (already loaded): 2026-03-24
# 2026-04-13 16:32:24,909 INFO:   ✓ Skipping (already loaded): 2026-03-25
# 2026-04-13 16:32:24,913 INFO:   ✓ Skipping (already loaded): 2026-03-26
# 2026-04-13 16:32:24,917 INFO:   ✓ Skipping (already loaded): 2026-03-27
# 2026-04-13 16:32:24,920 INFO:   ✓ Skipping (already loaded): 2026-03-30
# 2026-04-13 16:32:24,923 INFO:   ✓ Skipping (already loaded): 2026-03-31
# 2026-04-13 16:32:24,924 INFO:
# ============================================================
# 2026-04-13 16:32:24,924 INFO: FX Rate Load Process Completed
# 2026-04-13 16:32:24,924 INFO: ============================================================
#
# 2026-04-13 16:32:24,925 INFO:
# ============================================================
# 2026-04-13 16:32:24,925 INFO: STEP 1: DOWNLOAD  [StonEx]
# 2026-04-13 16:32:24,925 INFO: ============================================================
# 2026-04-13 16:32:25,910 WARNING:    ✗ Not found on S3: Trades20260101.csv
# 2026-04-13 16:32:25,961 WARNING:    ✗ Not found on S3: Trades20260102.csv
# 2026-04-13 16:32:25,967 INFO:    ✓ Already downloaded, queued for load: Trades20260105.csv
# 2026-04-13 16:32:25,971 INFO:    ✓ Already downloaded, queued for load: Trades20260106.csv
# 2026-04-13 16:32:25,976 INFO:    ✓ Already downloaded, queued for load: Trades20260107.csv
# 2026-04-13 16:32:25,980 INFO:    ✓ Already downloaded, queued for load: Trades20260108.csv
# 2026-04-13 16:32:25,983 INFO:    ✓ Already downloaded, queued for load: Trades20260109.csv
# 2026-04-13 16:32:25,987 INFO:    ✓ Already downloaded, queued for load: Trades20260112.csv
# 2026-04-13 16:32:25,990 INFO:    ✓ Already downloaded, queued for load: Trades20260113.csv
# 2026-04-13 16:32:25,994 INFO:    ✓ Already downloaded, queued for load: Trades20260114.csv
# 2026-04-13 16:32:25,998 INFO:    ✓ Already downloaded, queued for load: Trades20260115.csv
# 2026-04-13 16:32:26,001 INFO:    ✓ Already downloaded, queued for load: Trades20260116.csv
# 2026-04-13 16:32:26,005 INFO:    ✓ Already downloaded, queued for load: Trades20260119.csv
# 2026-04-13 16:32:26,008 INFO:    ✓ Already downloaded, queued for load: Trades20260120.csv
# 2026-04-13 16:32:26,012 INFO:    ✓ Already downloaded, queued for load: Trades20260121.csv
# 2026-04-13 16:32:26,016 INFO:    ✓ Already downloaded, queued for load: Trades20260122.csv
# 2026-04-13 16:32:26,019 INFO:    ✓ Already downloaded, queued for load: Trades20260123.csv
# 2026-04-13 16:32:26,022 INFO:    ✓ Already downloaded, queued for load: Trades20260126.csv
# 2026-04-13 16:32:26,026 INFO:    ✓ Already downloaded, queued for load: Trades20260127.csv
# 2026-04-13 16:32:26,029 INFO:    ✓ Already downloaded, queued for load: Trades20260128.csv
# 2026-04-13 16:32:26,033 INFO:    ✓ Already downloaded, queued for load: Trades20260129.csv
# 2026-04-13 16:32:26,036 INFO:    ✓ Already downloaded, queued for load: Trades20260130.csv
# 2026-04-13 16:32:26,039 INFO:    ✓ Already downloaded, queued for load: Trades20260202.csv
# 2026-04-13 16:32:26,042 INFO:    ✓ Already downloaded, queued for load: Trades20260203.csv
# 2026-04-13 16:32:26,047 INFO:    ✓ Already downloaded, queued for load: Trades20260204.csv
# 2026-04-13 16:32:26,051 INFO:    ✓ Already downloaded, queued for load: Trades20260205.csv
# 2026-04-13 16:32:26,054 INFO:    ✓ Already downloaded, queued for load: Trades20260206.csv
# 2026-04-13 16:32:26,057 INFO:    ✓ Already downloaded, queued for load: Trades20260209.csv
# 2026-04-13 16:32:26,060 INFO:    ✓ Already downloaded, queued for load: Trades20260210.csv
# 2026-04-13 16:32:26,064 INFO:    ✓ Already downloaded, queued for load: Trades20260211.csv
# 2026-04-13 16:32:26,069 INFO:    ✓ Already downloaded, queued for load: Trades20260212.csv
# 2026-04-13 16:32:26,072 INFO:    ✓ Already downloaded, queued for load: Trades20260213.csv
# 2026-04-13 16:32:26,075 INFO:    ✓ Already downloaded, queued for load: Trades20260216.csv
# 2026-04-13 16:32:26,079 INFO:    ✓ Already downloaded, queued for load: Trades20260217.csv
# 2026-04-13 16:32:26,083 INFO:    ✓ Already downloaded, queued for load: Trades20260218.csv
# 2026-04-13 16:32:26,086 INFO:    ✓ Already downloaded, queued for load: Trades20260219.csv
# 2026-04-13 16:32:26,089 INFO:    ✓ Already downloaded, queued for load: Trades20260220.csv
# 2026-04-13 16:32:26,094 INFO:    ✓ Already downloaded, queued for load: Trades20260223.csv
# 2026-04-13 16:32:26,098 INFO:    ✓ Already downloaded, queued for load: Trades20260224.csv
# 2026-04-13 16:32:26,102 INFO:    ✓ Already downloaded, queued for load: Trades20260225.csv
# 2026-04-13 16:32:26,105 INFO:    ✓ Already downloaded, queued for load: Trades20260226.csv
# 2026-04-13 16:32:26,108 INFO:    ✓ Already downloaded, queued for load: Trades20260227.csv
# 2026-04-13 16:32:26,112 INFO:    ✓ Already downloaded, queued for load: Trades20260302.csv
# 2026-04-13 16:32:26,115 INFO:    ✓ Already downloaded, queued for load: Trades20260303.csv
# 2026-04-13 16:32:26,118 INFO:    ✓ Already downloaded, queued for load: Trades20260304.csv
# 2026-04-13 16:32:26,122 INFO:    ✓ Already downloaded, queued for load: Trades20260305.csv
# 2026-04-13 16:32:26,125 INFO:    ✓ Already downloaded, queued for load: Trades20260306.csv
# 2026-04-13 16:32:26,128 INFO:    ✓ Already downloaded, queued for load: Trades20260309.csv
# 2026-04-13 16:32:26,132 INFO:    ✓ Already downloaded, queued for load: Trades20260310.csv
# 2026-04-13 16:32:26,135 INFO:    ✓ Already downloaded, queued for load: Trades20260311.csv
# 2026-04-13 16:32:26,138 INFO:    ✓ Already downloaded, queued for load: Trades20260312.csv
# 2026-04-13 16:32:26,142 INFO:    ✓ Already downloaded, queued for load: Trades20260313.csv
# 2026-04-13 16:32:26,145 INFO:    ✓ Already downloaded, queued for load: Trades20260316.csv
# 2026-04-13 16:32:26,149 INFO:    ✓ Already downloaded, queued for load: Trades20260317.csv
# 2026-04-13 16:32:26,152 INFO:    ✓ Already downloaded, queued for load: Trades20260318.csv
# 2026-04-13 16:32:26,155 INFO:    ✓ Already downloaded, queued for load: Trades20260319.csv
# 2026-04-13 16:32:26,160 INFO:    ✓ Already downloaded, queued for load: Trades20260320.csv
# 2026-04-13 16:32:26,163 INFO:    ✓ Already downloaded, queued for load: Trades20260323.csv
# 2026-04-13 16:32:26,166 INFO:    ✓ Already downloaded, queued for load: Trades20260324.csv
# 2026-04-13 16:32:26,170 INFO:    ✓ Already downloaded, queued for load: Trades20260325.csv
# 2026-04-13 16:32:26,173 INFO:    ✓ Already downloaded, queued for load: Trades20260326.csv
# 2026-04-13 16:32:26,176 INFO:    ✓ Already downloaded, queued for load: Trades20260327.csv
# 2026-04-13 16:32:26,180 INFO:    ✓ Already downloaded, queued for load: Trades20260330.csv
# 2026-04-13 16:32:26,184 INFO:    ✓ Already downloaded, queued for load: Trades20260331.csv
# 2026-04-13 16:32:26,185 INFO:
#    Total files ready for processing: 62
# 2026-04-13 16:32:26,186 INFO:
# ============================================================
# 2026-04-13 16:32:26,186 INFO: STEP 2 & 3: TRANSFORM + LOAD  [StonEx]
# 2026-04-13 16:32:26,186 INFO: ============================================================
# 2026-04-13 16:32:26,187 INFO:
#   Processing: Trades20260105.csv
# c:\Users\Axxela\Desktop\CART\exchanges\stonex.py:121: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, usecols=usecols)
# 2026-04-13 16:32:26,459 INFO:   Read 128047 raw records
# 2026-04-13 16:32:26,473 INFO:   128047 records after account filter
# 2026-04-13 16:32:26,581 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFEU'
#     Instrument Code: 'LCO'
#     Add this line  : ("ifeu", "lco") : ("??", "??"),
#
# 2026-04-13 16:32:26,582 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'NCT'
#     Add this line  : ("ifus", "nct") : ("??", "??"),
#
# 2026-04-13 16:32:26,582 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFLX'
#     Instrument Code: 'WSU'
#     Add this line  : ("iflx", "wsu") : ("??", "??"),
#
# 2026-04-13 16:32:26,583 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFEU'
#     Instrument Code: 'LGO'
#     Add this line  : ("ifeu", "lgo") : ("??", "??"),
#
# 2026-04-13 16:32:26,583 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFLX'
#     Instrument Code: 'CA'
#     Add this line  : ("iflx", "ca") : ("??", "??"),
#
# 2026-04-13 16:32:26,584 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'WCAJ'
#     Add this line  : ("ifus", "wcaj") : ("??", "??"),
#
# 2026-04-13 16:32:26,584 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'C'
#     Add this line  : ("cbt", "c") : ("??", "??"),
#
# 2026-04-13 16:32:26,584 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'NSU'
#     Add this line  : ("ifus", "nsu") : ("??", "??"),
#
# 2026-04-13 16:32:26,585 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CSM'
#     Add this line  : ("cbt", "csm") : ("??", "??"),
#
# 2026-04-13 16:32:26,585 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NC'
#     Add this line  : ("nyme", "nc") : ("??", "??"),
#
# 2026-04-13 16:32:26,586 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CSB'
#     Add this line  : ("cbt", "csb") : ("??", "??"),
#
# 2026-04-13 16:32:26,586 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MATF'
#     Instrument Code: 'ERAP'
#     Add this line  : ("matf", "erap") : ("??", "??"),
#
# 2026-04-13 16:32:26,587 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'NCFC'
#     Add this line  : ("ifus", "ncfc") : ("??", "??"),
#
# 2026-04-13 16:32:26,587 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CWH'
#     Add this line  : ("cbt", "cwh") : ("??", "??"),
#
# 2026-04-13 16:32:26,587 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'KWH'
#     Add this line  : ("cbt", "kwh") : ("??", "??"),
#
# 2026-04-13 16:32:26,588 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NOL'
#     Add this line  : ("nyme", "nol") : ("??", "??"),
#
# 2026-04-13 16:32:26,589 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CLLH'
#     Add this line  : ("cme", "cllh") : ("??", "??"),
#
# 2026-04-13 16:32:26,589 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CSO'
#     Add this line  : ("cbt", "cso") : ("??", "??"),
#
# 2026-04-13 16:32:26,591 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'NCA'
#     Add this line  : ("ifus", "nca") : ("??", "??"),
#
# 2026-04-13 16:32:26,591 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NYRB'
#     Add this line  : ("nyme", "nyrb") : ("??", "??"),
#
# 2026-04-13 16:32:26,592 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CFC2'
#     Add this line  : ("cme", "cfc2") : ("??", "??"),
#
# 2026-04-13 16:32:26,593 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CLC'
#     Add this line  : ("cme", "clc") : ("??", "??"),
#
# 2026-04-13 16:32:26,596 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'XGD'
#     Add this line  : ("comx", "xgd") : ("??", "??"),
#
# 2026-04-13 16:32:26,597 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFLX'
#     Instrument Code: 'ROBC'
#     Add this line  : ("iflx", "robc") : ("??", "??"),
#
# 2026-04-13 16:32:26,603 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MATF'
#     Instrument Code: 'EB2'
#     Add this line  : ("matf", "eb2") : ("??", "??"),
#
# 2026-04-13 16:32:26,605 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NCO'
#     Add this line  : ("nyme", "nco") : ("??", "??"),
#
# 2026-04-13 16:32:26,610 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFEU'
#     Instrument Code: 'IHOU'
#     Add this line  : ("ifeu", "ihou") : ("??", "??"),
#
# 2026-04-13 16:32:26,611 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFAD'
#     Instrument Code: 'IADM'
#     Add this line  : ("ifad", "iadm") : ("??", "??"),
#
# 2026-04-13 16:32:26,611 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFEU'
#     Instrument Code: 'IDBI'
#     Add this line  : ("ifeu", "idbi") : ("??", "??"),
#
# 2026-04-13 16:32:26,611 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFEU'
#     Instrument Code: 'WBS'
#     Add this line  : ("ifeu", "wbs") : ("??", "??"),
#
# 2026-04-13 16:32:26,637 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NYBZ'
#     Add this line  : ("nyme", "nybz") : ("??", "??"),
#
# 2026-04-13 16:32:26,641 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'ES'
#     Add this line  : ("cme", "es") : ("??", "??"),
#
# 2026-04-13 16:32:26,642 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'MNQ'
#     Add this line  : ("cme", "mnq") : ("??", "??"),
#
# 2026-04-13 16:32:26,670 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'NQ'
#     Add this line  : ("cme", "nq") : ("??", "??"),
#
# 2026-04-13 16:32:26,671 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'XCH'
#     Add this line  : ("comx", "xch") : ("??", "??"),
#
# 2026-04-13 16:32:26,673 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NDEX'
#     Instrument Code: 'ITTF'
#     Add this line  : ("ndex", "ittf") : ("??", "??"),
#
# 2026-04-13 16:32:26,675 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'NOJ'
#     Add this line  : ("ifus", "noj") : ("??", "??"),
#
# 2026-04-13 16:32:26,693 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'DMOQ'
#     Add this line  : ("nyme", "dmoq") : ("??", "??"),
#
# 2026-04-13 16:32:26,738 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'ECF'
#     Add this line  : ("nyme", "ecf") : ("??", "??"),
#
# 2026-04-13 16:32:26,789 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'HTT'
#     Add this line  : ("nyme", "htt") : ("??", "??"),
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFEU'
#     Instrument Code: 'LCO'
#     Add this line  : ("ifeu", "lco") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'NCT'
#     Add this line  : ("ifus", "nct") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFLX'
#     Instrument Code: 'WSU'
#     Add this line  : ("iflx", "wsu") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFEU'
#     Instrument Code: 'LGO'
#     Add this line  : ("ifeu", "lgo") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFLX'
#     Instrument Code: 'CA'
#     Add this line  : ("iflx", "ca") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'WCAJ'
#     Add this line  : ("ifus", "wcaj") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'C'
#     Add this line  : ("cbt", "c") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'NSU'
#     Add this line  : ("ifus", "nsu") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CSM'
#     Add this line  : ("cbt", "csm") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NC'
#     Add this line  : ("nyme", "nc") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CSB'
#     Add this line  : ("cbt", "csb") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MATF'
#     Instrument Code: 'ERAP'
#     Add this line  : ("matf", "erap") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'NCFC'
#     Add this line  : ("ifus", "ncfc") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CWH'
#     Add this line  : ("cbt", "cwh") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'KWH'
#     Add this line  : ("cbt", "kwh") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NOL'
#     Add this line  : ("nyme", "nol") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CLLH'
#     Add this line  : ("cme", "cllh") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CSO'
#     Add this line  : ("cbt", "cso") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'NCA'
#     Add this line  : ("ifus", "nca") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NYRB'
#     Add this line  : ("nyme", "nyrb") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CFC2'
#     Add this line  : ("cme", "cfc2") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CLC'
#     Add this line  : ("cme", "clc") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'XGD'
#     Add this line  : ("comx", "xgd") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFLX'
#     Instrument Code: 'ROBC'
#     Add this line  : ("iflx", "robc") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MATF'
#     Instrument Code: 'EB2'
#     Add this line  : ("matf", "eb2") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NCO'
#     Add this line  : ("nyme", "nco") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFEU'
#     Instrument Code: 'IHOU'
#     Add this line  : ("ifeu", "ihou") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFAD'
#     Instrument Code: 'IADM'
#     Add this line  : ("ifad", "iadm") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFEU'
#     Instrument Code: 'IDBI'
#     Add this line  : ("ifeu", "idbi") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFEU'
#     Instrument Code: 'WBS'
#     Add this line  : ("ifeu", "wbs") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NYBZ'
#     Add this line  : ("nyme", "nybz") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'ES'
#     Add this line  : ("cme", "es") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'MNQ'
#     Add this line  : ("cme", "mnq") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'NQ'
#     Add this line  : ("cme", "nq") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'XCH'
#     Add this line  : ("comx", "xch") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NDEX'
#     Instrument Code: 'ITTF'
#     Add this line  : ("ndex", "ittf") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'IFUS'
#     Instrument Code: 'NOJ'
#     Add this line  : ("ifus", "noj") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'DMOQ'
#     Add this line  : ("nyme", "dmoq") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'ECF'
#     Add this line  : ("nyme", "ecf") : ("??", "??"),
# 2026-04-13 16:32:26,789 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NWTT'
#     Add this line  : ("nyme", "nwtt") : ("??", "??"),
#
# 2026-04-13 16:32:26,900 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CEW'
#     Add this line  : ("cme", "cew") : ("??", "??"),
#
# 2026-04-13 16:32:26,900 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CBO'
#     Add this line  : ("cbt", "cbo") : ("??", "??"),
#
# 2026-04-13 16:32:26,901 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CTN2'
#     Add this line  : ("cbt", "ctn2") : ("??", "??"),
#
# 2026-04-13 16:32:26,901 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'TN1'
#     Add this line  : ("cbt", "tn1") : ("??", "??"),
#
# 2026-04-13 16:32:26,901 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'MGCO'
#     Add this line  : ("comx", "mgco") : ("??", "??"),
#
# 2026-04-13 16:32:26,902 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'CSIL'
#     Add this line  : ("comx", "csil") : ("??", "??"),
#
# 2026-04-13 16:32:26,902 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'M2K'
#     Add this line  : ("cme", "m2k") : ("??", "??"),
#
# 2026-04-13 16:32:26,903 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'JY'
#     Add this line  : ("cme", "jy") : ("??", "??"),
#
# 2026-04-13 16:32:26,903 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'RTY'
#     Add this line  : ("cme", "rty") : ("??", "??"),
#
# 2026-04-13 16:32:26,903 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'M1S'
#     Add this line  : ("comx", "m1s") : ("??", "??"),
#
# 2026-04-13 16:32:26,904 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'E1A'
#     Add this line  : ("cme", "e1a") : ("??", "??"),
#
# 2026-04-13 16:32:26,904 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'XAG'
#     Add this line  : ("comx", "xag") : ("??", "??"),
#
# 2026-04-13 16:32:26,904 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'G1M'
#     Add this line  : ("comx", "g1m") : ("??", "??"),
#
# 2026-04-13 16:32:26,905 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'ESM'
#     Add this line  : ("cme", "esm") : ("??", "??"),
#
# 2026-04-13 16:32:26,905 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'QNE'
#     Add this line  : ("cme", "qne") : ("??", "??"),
#
# 2026-04-13 16:32:26,905 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CQN2'
#     Add this line  : ("cme", "cqn2") : ("??", "??"),
#
# 2026-04-13 16:32:26,906 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'G1T'
#     Add this line  : ("comx", "g1t") : ("??", "??"),
#
# 2026-04-13 16:32:26,906 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'OG2'
#     Add this line  : ("comx", "og2") : ("??", "??"),
#
# 2026-04-13 16:32:26,909 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'LO2'
#     Add this line  : ("nyme", "lo2") : ("??", "??"),
#
# 2026-04-13 16:32:26,910 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'EW3'
#     Add this line  : ("cme", "ew3") : ("??", "??"),
#
# 2026-04-13 16:32:26,916 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'Q1A'
#     Add this line  : ("cme", "q1a") : ("??", "??"),
#
# 2026-04-13 16:32:26,926 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'EC'
#     Add this line  : ("cme", "ec") : ("??", "??"),
#
# 2026-04-13 16:32:26,934 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NPL'
#     Add this line  : ("nyme", "npl") : ("??", "??"),
#
# 2026-04-13 16:32:26,935 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CBRP'
#     Add this line  : ("cme", "cbrp") : ("??", "??"),
#
# 2026-04-13 16:32:26,937 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'CG1W'
#     Add this line  : ("comx", "cg1w") : ("??", "??"),
#
# 2026-04-13 16:32:26,939 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'SYP'
#     Add this line  : ("cme", "syp") : ("??", "??"),
#
# 2026-04-13 16:32:26,939 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'TTFN'
#     Add this line  : ("nyme", "ttfn") : ("??", "??"),
#
# 2026-04-13 16:32:26,942 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'SND'
#     Add this line  : ("lme", "snd") : ("??", "??"),
#
# 2026-04-13 16:32:26,942 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'AHD'
#     Add this line  : ("lme", "ahd") : ("??", "??"),
#
# 2026-04-13 16:32:26,943 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'ZSD'
#     Add this line  : ("lme", "zsd") : ("??", "??"),
#
# 2026-04-13 16:32:26,943 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'CAD'
#     Add this line  : ("lme", "cad") : ("??", "??"),
#
# 2026-04-13 16:32:26,943 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'NID'
#     Add this line  : ("lme", "nid") : ("??", "??"),
#
# 2026-04-13 16:32:26,944 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'PBD'
#     Add this line  : ("lme", "pbd") : ("??", "??"),
#
# 2026-04-13 16:32:27,030 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'OSFF'
#     Add this line  : ("cbt", "osff") : ("??", "??"),
#
# 2026-04-13 16:32:27,030 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CWD'
#     Add this line  : ("cbt", "cwd") : ("??", "??"),
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'HTT'
#     Add this line  : ("nyme", "htt") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NWTT'
#     Add this line  : ("nyme", "nwtt") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CEW'
#     Add this line  : ("cme", "cew") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CBO'
#     Add this line  : ("cbt", "cbo") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CTN2'
#     Add this line  : ("cbt", "ctn2") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'TN1'
#     Add this line  : ("cbt", "tn1") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'MGCO'
#     Add this line  : ("comx", "mgco") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'CSIL'
#     Add this line  : ("comx", "csil") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'M2K'
#     Add this line  : ("cme", "m2k") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'JY'
#     Add this line  : ("cme", "jy") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'RTY'
#     Add this line  : ("cme", "rty") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'M1S'
#     Add this line  : ("comx", "m1s") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'E1A'
#     Add this line  : ("cme", "e1a") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'XAG'
#     Add this line  : ("comx", "xag") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'G1M'
#     Add this line  : ("comx", "g1m") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'ESM'
#     Add this line  : ("cme", "esm") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'QNE'
#     Add this line  : ("cme", "qne") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CQN2'
#     Add this line  : ("cme", "cqn2") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'G1T'
#     Add this line  : ("comx", "g1t") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'OG2'
#     Add this line  : ("comx", "og2") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'LO2'
#     Add this line  : ("nyme", "lo2") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'EW3'
#     Add this line  : ("cme", "ew3") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'Q1A'
#     Add this line  : ("cme", "q1a") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'EC'
#     Add this line  : ("cme", "ec") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NPL'
#     Add this line  : ("nyme", "npl") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CBRP'
#     Add this line  : ("cme", "cbrp") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'CG1W'
#     Add this line  : ("comx", "cg1w") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'SYP'
#     Add this line  : ("cme", "syp") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'TTFN'
#     Add this line  : ("nyme", "ttfn") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'SND'
#     Add this line  : ("lme", "snd") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'AHD'
#     Add this line  : ("lme", "ahd") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'ZSD'
#     Add this line  : ("lme", "zsd") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'CAD'
#     Add this line  : ("lme", "cad") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'NID'
#     Add this line  : ("lme", "nid") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'LME'
#     Instrument Code: 'PBD'
#     Add this line  : ("lme", "pbd") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'OSFF'
#     Add this line  : ("cbt", "osff") : ("??", "??"),
# 2026-04-13 16:32:27,031 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CKWD'
#     Add this line  : ("cbt", "ckwd") : ("??", "??"),
#
# 2026-04-13 16:32:27,054 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NMCL'
#     Add this line  : ("nyme", "nmcl") : ("??", "??"),
#
# 2026-04-13 16:32:27,055 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NYHH'
#     Add this line  : ("nyme", "nyhh") : ("??", "??"),
#
# 2026-04-13 16:32:27,093 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MATF'
#     Instrument Code: 'EMA'
#     Add this line  : ("matf", "ema") : ("??", "??"),
#
# 2026-04-13 16:32:27,098 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'XBR'
#     Add this line  : ("cme", "xbr") : ("??", "??"),
#
# 2026-04-13 16:32:27,105 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'SGX'
#     Instrument Code: 'GINS'
#     Add this line  : ("sgx", "gins") : ("??", "??"),
#
# 2026-04-13 16:32:27,105 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CSIR'
#     Add this line  : ("cme", "csir") : ("??", "??"),
#
# 2026-04-13 16:32:27,106 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'CSO4'
#     Add this line  : ("comx", "cso4") : ("??", "??"),
#
# 2026-04-13 16:32:27,110 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'CSO2'
#     Add this line  : ("comx", "cso2") : ("??", "??"),
#
# 2026-04-13 16:32:27,132 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'EW2'
#     Add this line  : ("cme", "ew2") : ("??", "??"),
#
# 2026-04-13 16:32:27,133 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'Q1B'
#     Add this line  : ("cme", "q1b") : ("??", "??"),
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CWD'
#     Add this line  : ("cbt", "cwd") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CBT'
#     Instrument Code: 'CKWD'
#     Add this line  : ("cbt", "ckwd") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NMCL'
#     Add this line  : ("nyme", "nmcl") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NYHH'
#     Add this line  : ("nyme", "nyhh") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MATF'
#     Instrument Code: 'EMA'
#     Add this line  : ("matf", "ema") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'XBR'
#     Add this line  : ("cme", "xbr") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'SGX'
#     Instrument Code: 'GINS'
#     Add this line  : ("sgx", "gins") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'CSIR'
#     Add this line  : ("cme", "csir") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'CSO4'
#     Add this line  : ("comx", "cso4") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'COMX'
#     Instrument Code: 'CSO2'
#     Add this line  : ("comx", "cso2") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'EW2'
#     Add this line  : ("cme", "ew2") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CME'
#     Instrument Code: 'Q1B'
#     Add this line  : ("cme", "q1b") : ("??", "??"),
# 2026-04-13 16:32:27,249 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NYME'
#     Instrument Code: 'NPT'
#     Add this line  : ("nyme", "npt") : ("??", "??"),
#
# 2026-04-13 16:32:27,273 WARNING:
# ...
#     Exchange Code  : 'MES'
#     Instrument Code: 'ESM'
#     Add this line  : ("mes", "esm") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NQ'
#     Instrument Code: 'NQ'
#     Add this line  : ("nq", "nq") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MNQ'
#     Instrument Code: 'MNQ'
#     Add this line  : ("mnq", "mnq") : ("??", "??"),
# 2026-04-13 16:33:22,952 INFO:   Transform complete: 744 records ready
# 2026-04-13 16:33:22,987 INFO:   Inserted rows 1–500 of 744
# 2026-04-13 16:33:22,997 INFO:   Inserted rows 501–744 of 744
# 2026-04-13 16:33:23,312 INFO:   ✓ USD conversion complete for 2026-03-30
# 2026-04-13 16:33:23,316 INFO:   ✓ Loaded 744 records from Trades20260330.csv
# 2026-04-13 16:33:23,316 INFO:
#   Processing: Trades20260331.csv
# c:\Users\Axxela\Desktop\CART\exchanges\stonex.py:121: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, usecols=usecols)
# 2026-04-13 16:33:23,564 INFO:   Read 88849 raw records
# 2026-04-13 16:33:23,586 INFO:   88849 records after account filter
# 2026-04-13 16:33:23,710 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'EW'
#     Instrument Code: 'CEW'
#     Add this line  : ("ew", "cew") : ("??", "??"),
#
# 2026-04-13 16:33:23,712 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'QNE'
#     Instrument Code: 'QNE'
#     Add this line  : ("qne", "qne") : ("??", "??"),
#
# 2026-04-13 16:33:23,718 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'G5T'
#     Instrument Code: 'G5T'
#     Add this line  : ("g5t", "g5t") : ("??", "??"),
#
# 2026-04-13 16:33:23,723 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'Q1C'
#     Instrument Code: 'Q1C'
#     Add this line  : ("q1c", "q1c") : ("??", "??"),
#
# 2026-04-13 16:33:23,724 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'E1C'
#     Instrument Code: 'E1C'
#     Add this line  : ("e1c", "e1c") : ("??", "??"),
#
# 2026-04-13 16:33:23,724 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'G1W'
#     Instrument Code: 'CG1W'
#     Add this line  : ("g1w", "cg1w") : ("??", "??"),
#
# 2026-04-13 16:33:23,725 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'Q1D'
#     Instrument Code: 'Q1D'
#     Add this line  : ("q1d", "q1d") : ("??", "??"),
#
# 2026-04-13 16:33:23,726 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'G1M'
#     Instrument Code: 'G1M'
#     Add this line  : ("g1m", "g1m") : ("??", "??"),
#
# 2026-04-13 16:33:23,727 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'E1A'
#     Instrument Code: 'E1A'
#     Add this line  : ("e1a", "e1a") : ("??", "??"),
#
# 2026-04-13 16:33:23,727 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'G'
#     Instrument Code: 'LGO'
#     Add this line  : ("g", "lgo") : ("??", "??"),
#
# 2026-04-13 16:33:23,732 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'EW2'
#     Instrument Code: 'EW2'
#     Add this line  : ("ew2", "ew2") : ("??", "??"),
#
# 2026-04-13 16:33:23,736 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'W'
#     Instrument Code: 'WSU'
#     Add this line  : ("w", "wsu") : ("??", "??"),
#
# 2026-04-13 16:33:23,737 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'EW3'
#     Instrument Code: 'EW3'
#     Add this line  : ("ew3", "ew3") : ("??", "??"),
#
# 2026-04-13 16:33:23,746 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MZW'
#     Instrument Code: 'MZW'
#     Add this line  : ("mzw", "mzw") : ("??", "??"),
#
# 2026-04-13 16:33:23,747 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MBT'
#     Instrument Code: 'CMBT'
#     Add this line  : ("mbt", "cmbt") : ("??", "??"),
#
# 2026-04-13 16:33:23,748 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MNG'
#     Instrument Code: 'NMNG'
#     Add this line  : ("mng", "nmng") : ("??", "??"),
#
# 2026-04-13 16:33:23,749 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'OG'
#     Instrument Code: 'XGD'
#     Add this line  : ("og", "xgd") : ("??", "??"),
#
# 2026-04-13 16:33:23,750 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'SO'
#     Instrument Code: 'XAG'
#     Add this line  : ("so", "xag") : ("??", "??"),
#
# 2026-04-13 16:33:23,752 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'SIR'
#     Instrument Code: 'CSIR'
#     Add this line  : ("sir", "csir") : ("??", "??"),
#
# 2026-04-13 16:33:23,765 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'HO'
#     Instrument Code: 'NOL'
#     Add this line  : ("ho", "nol") : ("??", "??"),
#
# 2026-04-13 16:33:23,799 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CT'
#     Instrument Code: 'NCT'
#     Add this line  : ("ct", "nct") : ("??", "??"),
#
# 2026-04-13 16:33:23,818 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CC'
#     Instrument Code: 'NCA'
#     Add this line  : ("cc", "nca") : ("??", "??"),
#
# 2026-04-13 16:33:23,819 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'C'
#     Instrument Code: 'CA'
#     Add this line  : ("c", "ca") : ("??", "??"),
#
# 2026-04-13 16:33:23,831 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NID'
#     Instrument Code: 'NID'
#     Add this line  : ("nid", "nid") : ("??", "??"),
#
# 2026-04-13 16:33:23,838 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'ALI'
#     Instrument Code: 'ALIC'
#     Add this line  : ("ali", "alic") : ("??", "??"),
#
# 2026-04-13 16:33:23,902 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'EMA'
#     Instrument Code: 'EMA'
#     Add this line  : ("ema", "ema") : ("??", "??"),
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'EW'
#     Instrument Code: 'CEW'
#     Add this line  : ("ew", "cew") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'QNE'
#     Instrument Code: 'QNE'
#     Add this line  : ("qne", "qne") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'G5T'
#     Instrument Code: 'G5T'
#     Add this line  : ("g5t", "g5t") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'Q1C'
#     Instrument Code: 'Q1C'
#     Add this line  : ("q1c", "q1c") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'E1C'
#     Instrument Code: 'E1C'
#     Add this line  : ("e1c", "e1c") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'G1W'
#     Instrument Code: 'CG1W'
#     Add this line  : ("g1w", "cg1w") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'Q1D'
#     Instrument Code: 'Q1D'
#     Add this line  : ("q1d", "q1d") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'G1M'
#     Instrument Code: 'G1M'
#     Add this line  : ("g1m", "g1m") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'E1A'
#     Instrument Code: 'E1A'
#     Add this line  : ("e1a", "e1a") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'G'
#     Instrument Code: 'LGO'
#     Add this line  : ("g", "lgo") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'EW2'
#     Instrument Code: 'EW2'
#     Add this line  : ("ew2", "ew2") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'W'
#     Instrument Code: 'WSU'
#     Add this line  : ("w", "wsu") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'EW3'
#     Instrument Code: 'EW3'
#     Add this line  : ("ew3", "ew3") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MZW'
#     Instrument Code: 'MZW'
#     Add this line  : ("mzw", "mzw") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MBT'
#     Instrument Code: 'CMBT'
#     Add this line  : ("mbt", "cmbt") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MNG'
#     Instrument Code: 'NMNG'
#     Add this line  : ("mng", "nmng") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'OG'
#     Instrument Code: 'XGD'
#     Add this line  : ("og", "xgd") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'SO'
#     Instrument Code: 'XAG'
#     Add this line  : ("so", "xag") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'SIR'
#     Instrument Code: 'CSIR'
#     Add this line  : ("sir", "csir") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'HO'
#     Instrument Code: 'NOL'
#     Add this line  : ("ho", "nol") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CT'
#     Instrument Code: 'NCT'
#     Add this line  : ("ct", "nct") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'CC'
#     Instrument Code: 'NCA'
#     Add this line  : ("cc", "nca") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'C'
#     Instrument Code: 'CA'
#     Add this line  : ("c", "ca") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NID'
#     Instrument Code: 'NID'
#     Add this line  : ("nid", "nid") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'ALI'
#     Instrument Code: 'ALIC'
#     Add this line  : ("ali", "alic") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'EMA'
#     Instrument Code: 'EMA'
#     Add this line  : ("ema", "ema") : ("??", "??"),
# 2026-04-13 16:33:23,924 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : '17'
#     Instrument Code: 'CBO'
#     Add this line  : ("17", "cbo") : ("??", "??"),
#
# 2026-04-13 16:33:23,925 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : '21'
#     Instrument Code: 'TN1'
#     Add this line  : ("21", "tn1") : ("??", "??"),
#
# 2026-04-13 16:33:23,926 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'ES'
#     Instrument Code: 'ES'
#     Add this line  : ("es", "es") : ("??", "??"),
#
# 2026-04-13 16:33:23,927 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MES'
#     Instrument Code: 'ESM'
#     Add this line  : ("mes", "esm") : ("??", "??"),
#
# 2026-04-13 16:33:23,928 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MNQ'
#     Instrument Code: 'MNQ'
#     Add this line  : ("mnq", "mnq") : ("??", "??"),
#
# 2026-04-13 16:33:23,934 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NQ'
#     Instrument Code: 'NQ'
#     Add this line  : ("nq", "nq") : ("??", "??"),
#
# 2026-04-13 16:33:24,035 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MGC'
#     Instrument Code: 'MGCO'
#     Add this line  : ("mgc", "mgco") : ("??", "??"),
#
# 2026-04-13 16:33:24,089 WARNING:
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : '26'
#     Instrument Code: 'CTN2'
#     Add this line  : ("26", "ctn2") : ("??", "??"),
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : '17'
#     Instrument Code: 'CBO'
#     Add this line  : ("17", "cbo") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : '21'
#     Instrument Code: 'TN1'
#     Add this line  : ("21", "tn1") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'ES'
#     Instrument Code: 'ES'
#     Add this line  : ("es", "es") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MES'
#     Instrument Code: 'ESM'
#     Add this line  : ("mes", "esm") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MNQ'
#     Instrument Code: 'MNQ'
#     Add this line  : ("mnq", "mnq") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'NQ'
#     Instrument Code: 'NQ'
#     Add this line  : ("nq", "nq") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : 'MGC'
#     Instrument Code: 'MGCO'
#     Add this line  : ("mgc", "mgco") : ("??", "??"),
#
#
# ⚠️  UNMAPPED CODE FOUND — please add to ctrcode_mapping in exchanges/stonex.py:
#     Exchange Code  : '26'
#     Instrument Code: 'CTN2'
#     Add this line  : ("26", "ctn2") : ("??", "??"),
# 2026-04-13 16:33:24,971 INFO:   Transform complete: 805 records ready
# 2026-04-13 16:33:25,006 INFO:   Inserted rows 1–500 of 805
# 2026-04-13 16:33:25,017 INFO:   Inserted rows 501–805 of 805
# 2026-04-13 16:33:25,320 INFO:   ✓ USD conversion complete for 2026-03-31
# 2026-04-13 16:33:25,323 INFO:   ✓ Loaded 805 records from Trades20260331.csv
# 2026-04-13 16:33:25,324 INFO:
# ============================================================
# 2026-04-13 16:33:25,324 INFO: PIPELINE COMPLETE  [StonEx]
# 2026-04-13 16:33:25,325 INFO: ============================================================
# 2026-04-13 16:33:25,325 INFO:   Files downloaded : 62
# 2026-04-13 16:33:25,326 INFO:   Files loaded     : 62
# 2026-04-13 16:33:25,327 INFO:   Files skipped    : 0
# 2026-04-13 16:33:25,327 INFO:   Files failed     : 0
# 2026-04-13 16:33:25,328 INFO: ============================================================
# {'downloaded': 62, 'loaded': 62, 'skipped': 0, 'failed': 0}

# %%
from cores.pipeline import run_pipeline
from exchanges.marexus import EXCHANGE_CONFIG, step_transform, step_load

run_pipeline(
    config=EXCHANGE_CONFIG,
    transform_func=step_transform,
    load_func=step_load,
    credentials_file="aws_credentials.json",
    start_date_str="20260101",
    end_date_str="20260331"
)
# Out:
# 2026-04-13 16:33:25,337 INFO:
# ============================================================
# 2026-04-13 16:33:25,338 INFO: STEP 1: DOWNLOAD  [Maexus]
# 2026-04-13 16:33:25,339 INFO: ============================================================
# 2026-04-13 16:33:26,715 WARNING:    ✗ Not found on S3: Marex Trades and Fees_20
INFO:    ✓ Already downloaded, queued for load: Marex Trades and Fees_20260326.csv
# 2026-04-13 16:33:29,338 INFO:    ✓ Already downloaded, queued for load: Marex Trades and Fees_20260327.csv
# 2026-04-13 16:33:29,344 INFO:    ✓ Already downloaded, queued for load: Marex Trades and Fees_20260330.csv
# 2026-04-13 16:33:29,350 INFO:    ✓ Already downloaded, queued for load: Marex Trades and Fees_20260331.csv
# 2026-04-13 16:33:29,351 INFO:
#    Total files ready for processing: 21
# 2026-04-13 16:33:29,351 INFO:
# ============================================================
# 2026-04-13 16:33:29,352 INFO: STEP 2 & 3: TRANSFORM + LOAD  [Maexus]
# 2026-04-13 16:33:29,353 INFO: ============================================================
# 2026-04-13 16:33:29,353 INFO:
#   Processing: Marex Trades and Fees_20260303.csv
# --- Starting Transform for Marex Trades and Fees_20260303.csv ---
#    -> S3: Downloading reference SYM/2026/03/03/TRD_SYM_20260303.csv...
# 2026-04-13 16:33:46,229 INFO:
#   Processing: Marex Trades and Fees_20260304.csv
#    Ref lookup built: 139 unique contractcode entries
#    Mapping result: 234 matched, 0 unmatched
# ✅ Transform complete — rows: 234, MISSING exchange: 0
#    Loading 234 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260303.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260304.csv ---
#    -> S3: Downloading reference SYM/2026/03/04/TRD_SYM_20260304.csv...
# 2026-04-13 16:33:59,882 INFO:
#   Processing: Marex Trades and Fees_20260305.csv
#    Ref lookup built: 136 unique contractcode entries
#    Mapping result: 194 matched, 0 unmatched
# ✅ Transform complete — rows: 194, MISSING exchange: 0
#    Loading 194 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260304.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260305.csv ---
#    -> S3: Downloading reference SYM/2026/03/05/TRD_SYM_20260305.csv...
# 2026-04-13 16:34:14,194 INFO:
#   Processing: Marex Trades and Fees_20260306.csv
#    Ref lookup built: 144 unique contractcode entries
#    Mapping result: 186 matched, 0 unmatched
# ✅ Transform complete — rows: 186, MISSING exchange: 0
#    Loading 186 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260305.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260306.csv ---
#    -> S3: Downloading reference SYM/2026/03/06/TRD_SYM_20260306.csv...
# 2026-04-13 16:34:30,090 INFO:
#   Processing: Marex Trades and Fees_20260309.csv
#    Ref lookup built: 137 unique contractcode entries
#    Mapping result: 262 matched, 0 unmatched
# ✅ Transform complete — rows: 262, MISSING exchange: 0
#    Loading 262 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260306.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260309.csv ---
#    -> S3: Downloading reference SYM/2026/03/09/TRD_SYM_20260309.csv...
# c:\Users\Axxela\Desktop\CART\exchanges\marexus.py:313: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# 2026-04-13 16:34:53,368 INFO:
#   Processing: Marex Trades and Fees_20260310.csv
#    Ref lookup built: 131 unique contractcode entries
#    Mapping result: 296 matched, 0 unmatched
# ✅ Transform complete — rows: 296, MISSING exchange: 0
#    Loading 296 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260309.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260310.csv ---
#    -> S3: Downloading reference SYM/2026/03/10/TRD_SYM_20260310.csv...
# c:\Users\Axxela\Desktop\CART\exchanges\marexus.py:313: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# 2026-04-13 16:35:09,821 INFO:
#   Processing: Marex Trades and Fees_20260311.csv
#    Ref lookup built: 126 unique contractcode entries
#    Mapping result: 209 matched, 0 unmatched
# ✅ Transform complete — rows: 209, MISSING exchange: 0
#    Loading 209 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260310.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260311.csv ---
#    -> S3: Downloading reference SYM/2026/03/11/TRD_SYM_20260311.csv...
# 2026-04-13 16:35:25,894 INFO:
#   Processing: Marex Trades and Fees_20260312.csv
#    Ref lookup built: 123 unique contractcode entries
#    Mapping result: 287 matched, 0 unmatched
# ✅ Transform complete — rows: 287, MISSING exchange: 0
#    Loading 287 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260311.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260312.csv ---
#    -> S3: Downloading reference SYM/2026/03/12/TRD_SYM_20260312.csv...
# c:\Users\Axxela\Desktop\CART\exchanges\marexus.py:313: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# 2026-04-13 16:35:40,323 INFO:
#   Processing: Marex Trades and Fees_20260313.csv
#    Ref lookup built: 130 unique contractcode entries
#    Mapping result: 168 matched, 0 unmatched
# ✅ Transform complete — rows: 168, MISSING exchange: 0
#    Loading 168 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260312.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260313.csv ---
#    -> S3: Downloading reference SYM/2026/03/13/TRD_SYM_20260313.csv...
# c:\Users\Axxela\Desktop\CART\exchanges\marexus.py:313: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# 2026-04-13 16:35:53,211 INFO:
#   Processing: Marex Trades and Fees_20260316.csv
#    Ref lookup built: 130 unique contractcode entries
#    Mapping result: 417 matched, 0 unmatched
# ✅ Transform complete — rows: 417, MISSING exchange: 0
#    Loading 417 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260313.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260316.csv ---
#    -> S3: Downloading reference SYM/2026/03/16/TRD_SYM_20260316.csv...
# 2026-04-13 16:36:04,552 INFO:
#   Processing: Marex Trades and Fees_20260317.csv
#    Ref lookup built: 123 unique contractcode entries
#    Mapping result: 296 matched, 0 unmatched
# ✅ Transform complete — rows: 296, MISSING exchange: 0
#    Loading 296 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260316.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260317.csv ---
#    -> S3: Downloading reference SYM/2026/03/17/TRD_SYM_20260317.csv...
# 2026-04-13 16:36:20,833 INFO:
#   Processing: Marex Trades and Fees_20260318.csv
#    Ref lookup built: 124 unique contractcode entries
#    Mapping result: 180 matched, 0 unmatched
# ✅ Transform complete — rows: 180, MISSING exchange: 0
#    Loading 180 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260317.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260318.csv ---
#    -> S3: Downloading reference SYM/2026/03/18/TRD_SYM_20260318.csv...
# 2026-04-13 16:36:31,155 INFO:
#   Processing: Marex Trades and Fees_20260319.csv
#    Ref lookup built: 129 unique contractcode entries
#    Mapping result: 91 matched, 0 unmatched
# ✅ Transform complete — rows: 91, MISSING exchange: 0
#    Loading 91 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260318.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260319.csv ---
#    -> S3: Downloading reference SYM/2026/03/19/TRD_SYM_20260319.csv...
# 2026-04-13 16:36:45,283 INFO:
#   Processing: Marex Trades and Fees_20260320.csv
#    Ref lookup built: 127 unique contractcode entries
#    Mapping result: 146 matched, 0 unmatched
# ✅ Transform complete — rows: 146, MISSING exchange: 0
#    Loading 146 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260319.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260320.csv ---
#    -> S3: Downloading reference SYM/2026/03/20/TRD_SYM_20260320.csv...
# 2026-04-13 16:36:55,678 INFO:
#   Processing: Marex Trades and Fees_20260323.csv
#    Ref lookup built: 113 unique contractcode entries
#    Mapping result: 223 matched, 0 unmatched
# ✅ Transform complete — rows: 223, MISSING exchange: 0
#    Loading 223 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260320.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260323.csv ---
#    -> S3: Downloading reference SYM/2026/03/23/TRD_SYM_20260323.csv...
# 2026-04-13 16:37:13,251 INFO:
#   Processing: Marex Trades and Fees_20260324.csv
#    Ref lookup built: 121 unique contractcode entries
#    Mapping result: 225 matched, 0 unmatched
# ✅ Transform complete — rows: 225, MISSING exchange: 0
#    Loading 225 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260323.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260324.csv ---
#    -> S3: Downloading reference SYM/2026/03/24/TRD_SYM_20260324.csv...
# 2026-04-13 16:37:25,137 INFO:
#   Processing: Marex Trades and Fees_20260325.csv
#    Ref lookup built: 119 unique contractcode entries
#    Mapping result: 223 matched, 0 unmatched
# ✅ Transform complete — rows: 223, MISSING exchange: 0
#    Loading 223 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260324.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260325.csv ---
#    -> S3: Downloading reference SYM/2026/03/25/TRD_SYM_20260325.csv...
# c:\Users\Axxela\Desktop\CART\exchanges\marexus.py:313: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# 2026-04-13 16:37:36,589 INFO:
#   Processing: Marex Trades and Fees_20260326.csv
#    Ref lookup built: 130 unique contractcode entries
#    Mapping result: 234 matched, 0 unmatched
# ✅ Transform complete — rows: 234, MISSING exchange: 0
#    Loading 234 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260325.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260326.csv ---
#    -> S3: Downloading reference SYM/2026/03/26/TRD_SYM_20260326.csv...
# 2026-04-13 16:37:48,570 INFO:
#   Processing: Marex Trades and Fees_20260327.csv
#    Ref lookup built: 122 unique contractcode entries
#    Mapping result: 214 matched, 0 unmatched
# ✅ Transform complete — rows: 214, MISSING exchange: 0
#    Loading 214 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260326.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260327.csv ---
#    -> S3: Downloading reference SYM/2026/03/27/TRD_SYM_20260327.csv...
# 2026-04-13 16:37:58,375 INFO:
#   Processing: Marex Trades and Fees_20260330.csv
#    Ref lookup built: 126 unique contractcode entries
#    Mapping result: 258 matched, 0 unmatched
# ✅ Transform complete — rows: 258, MISSING exchange: 0
#    Loading 258 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260327.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260330.csv ---
#    -> S3: Downloading reference SYM/2026/03/30/TRD_SYM_20260330.csv...
# 2026-04-13 16:38:07,656 INFO:
#   Processing: Marex Trades and Fees_20260331.csv
#    Ref lookup built: 122 unique contractcode entries
#    Mapping result: 359 matched, 0 unmatched
# ✅ Transform complete — rows: 359, MISSING exchange: 0
#    Loading 359 rows into maexus_trades_march...
# ✅ Loaded Marex Trades and Fees_20260330.csv successfully.
#
# --- Starting Transform for Marex Trades and Fees_20260331.csv ---
#    -> S3: Downloading reference SYM/2026/03/31/TRD_SYM_20260331.csv...
#    Ref lookup built: 125 unique contractcode entries
#    Mapping result: 356 matched, 28 unmatched
#    Still unmatched (add to STATIC_EXCHANGE_MAP): ['OXY' 'APD' 'BIIB' 'COST' 'CTRA' 'CME' 'CSCO' 'DVN' 'FOXA' 'DOC' 'HSY'
#  'MKC' 'OKE' 'VRSN']
# ✅ Transform complete — rows: 384, MISSING exchange: 28
#    Loading 384 rows into maexus_trades_march...
# 2026-04-13 16:38:23,713 INFO:
# ============================================================
# 2026-04-13 16:38:23,714 INFO: PIPELINE COMPLETE  [Maexus]
# 2026-04-13 16:38:23,715 INFO: ============================================================
# 2026-04-13 16:38:23,715 INFO:   Files downloaded : 21
# 2026-04-13 16:38:23,716 INFO:   Files loaded     : 21
# 2026-04-13 16:38:23,716 INFO:   Files skipped    : 0
# 2026-04-13 16:38:23,717 INFO:   Files failed     : 0
# 2026-04-13 16:38:23,718 INFO: ============================================================
# ✅ Loaded Marex Trades and Fees_20260331.csv successfully.
# {'downloaded': 21, 'loaded': 21, 'skipped': 0, 'failed': 0}

# %%
# main.py

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s: %(message)s')
import sys
import os
sys.path.insert(0, os.path.abspath('.'))

from fx_loader import load_fx_rates
from cores.pipeline import run_pipeline

from exchanges.marex import EXCHANGE_CONFIG as MAREX_CONFIG, step_transform as marex_transform, step_load as marex_load



START = "20260101"
END   = "20260331"

# 1. Load FX rates first
load_fx_rates(START, END)

# 2. Run Marex
run_pipeline(
    config=MAREX_CONFIG,
    transform_func=marex_transform,
    load_func=marex_load,
    credentials_file="aws_credentials.json",
    start_date_str=START,
    end_date_str=END
)
# Out:
# 2026-04-13 16:38:23,728 INFO:
# ============================================================
# 2026-04-13 16:38:23,729 INFO: Starting FX Rate Load Process
# 2026-04-13 16:38:23,729 INFO: ============================================================
# 2026-04-13 16:38:23,750 INFO:   ✓ Skipping (already loaded): 2026-01-01
# 2026-04-13 16:38:23,759 INFO:   ✓ Skipping (already loaded): 2026-01-02
# 2026-04-13 16:38:23,767 INFO:   ✓ Skipping (already loaded): 2026-01-05
# 2026-04-13 16:38:23,774 INFO:   ✓ Skipping (already loaded): 2026-01-06
# 2026-04-13 16:38:23,782 INFO:   ✓ Skipping (already loaded): 2026-01-07
# 2026-04-13 16:38:23,790 INFO:   ✓ Skipping (already loaded): 2026-01-08
# 2026-04-13 16:38:23,797 INFO:   ✓ Skipping (already loaded): 2026-01-09
# 2026-04-13 16:38:23,804 INFO:   ✓ Skipping (already loaded): 2026-01-12
# 2026-04-13 16:38:23,810 INFO:   ✓ Skipping (already loaded): 2026-01-13
# 2026-04-13 16:38:23,816 INFO:   ✓ Skipping (already loaded): 2026-01-14
# 2026-04-13 16:38:23,823 INFO:   ✓ Skipping (already loaded): 2026-01-15
# 2026-04-13 16:38:23,829 INFO:   ✓ Skipping (already loaded): 2026-01-16
# 2026-04-13 16:38:23,835 INFO:   ✓ Skipping (already loaded): 2026-01-19
# 2026-04-13 16:38:23,841 INFO:   ✓ Skipping (already loaded): 2026-01-20
# 2026-04-13 16:38:23,848 INFO:   ✓ Skipping (already loaded): 2026-01-21
# 2026-04-13 16:38:23,855 INFO:   ✓ Skipping (already loaded): 2026-01-22
# 2026-04-13 16:38:23,861 INFO:   ✓ Skipping (already loaded): 2026-01-23
# 2026-04-13 16:38:23,868 INFO:   ✓ Skipping (already loaded): 2026-01-26
# 2026-04-13 16:38:23,874 INFO:   ✓ Skipping (already loaded): 2026-01-27
# 2026-04-13 16:38:23,881 INFO:   ✓ Skipping (already loaded): 2026-01-28
# 2026-04-13 16:38:23,887 INFO:   ✓ Skipping (already loaded): 2026-01-29
# 2026-04-13 16:38:23,893 INFO:   ✓ Skipping (already loaded): 2026-01-30
# 2026-04-13 16:38:23,900 INFO:   ✓ Skipping (already loaded): 2026-02-02
# 2026-04-13 16:38:23,907 INFO:   ✓ Skipping (already loaded): 2026-02-03
# 2026-04-13 16:38:23,919 INFO:   ✓ Skipping (already loaded): 2026-02-04
# 2026-04-13 16:38:23,926 INFO:   ✓ Skipping (already loaded): 2026-02-05
# 2026-04-13 16:38:23,932 INFO:   ✓ Skipping (already loaded): 2026-02-06
# 2026-04-13 16:38:23,939 INFO:   ✓ Skipping (already loaded): 2026-02-09
# 2026-04-13 16:38:23,946 INFO:   ✓ Skipping (already loaded): 2026-02-10
# 2026-04-13 16:38:23,953 INFO:   ✓ Skipping (already loaded): 2026-02-11
# 2026-04-13 16:38:23,959 INFO:   ✓ Skipping (already loaded): 2026-02-12
# 2026-04-13 16:38:23,965 INFO:   ✓ Skipping (already loaded): 2026-02-13
# 2026-04-13 16:38:23,973 INFO:   ✓ Skipping (already loaded): 2026-02-16
# 2026-04-13 16:38:23,981 INFO:   ✓ Skipping (already loaded): 2026-02-17
# 2026-04-13 16:38:23,989 INFO:   ✓ Skipping (already loaded): 2026-02-18
# 2026-04-13 16:38:23,995 INFO:   ✓ Skipping (already loaded): 2026-02-19
# 2026-04-13 16:38:24,002 INFO:   ✓ Skipping (already loaded): 2026-02-20
# 2026-04-13 16:38:24,009 INFO:   ✓ Skipping (already loaded): 2026-02-23
# 2026-04-13 16:38:24,015 INFO:   ✓ Skipping (already loaded): 2026-02-24
# 2026-04-13 16:38:24,022 INFO:   ✓ Skipping (already loaded): 2026-02-25
# 2026-04-13 16:38:24,030 INFO:   ✓ Skipping (already loaded): 2026-02-26
# 2026-04-13 16:38:24,038 INFO:   ✓ Skipping (already loaded): 2026-02-27
# 2026-04-13 16:38:24,044 INFO:   ✓ Skipping (already loaded): 2026-03-02
# 2026-04-13 16:38:24,049 INFO:   ✓ Skipping (already loaded): 2026-03-03
# 2026-04-13 16:38:24,055 INFO:   ✓ Skipping (already loaded): 2026-03-04
# 2026-04-13 16:38:24,060 INFO:   ✓ Skipping (already loaded): 2026-03-05
# 2026-04-13 16:38:24,067 INFO:   ✓ Skipping (already loaded): 2026-03-06
# 2026-04-13 16:38:24,072 INFO:   ✓ Skipping (already loaded): 2026-03-09
# 2026-04-13 16:38:24,078 INFO:   ✓ Skipping (already loaded): 2026-03-10
# 2026-04-13 16:38:24,085 INFO:   ✓ Skipping (already loaded): 2026-03-11
# 2026-04-13 16:38:24,091 INFO:   ✓ Skipping (already loaded): 2026-03-12
# 2026-04-13 16:38:24,098 INFO:   ✓ Skipping (already loaded): 2026-03-13
# 2026-04-13 16:38:24,104 INFO:   ✓ Skipping (already loaded): 2026-03-16
# 2026-04-13 16:38:24,110 INFO:   ✓ Skipping (already loaded): 2026-03-17
# 2026-04-13 16:38:24,116 INFO:   ✓ Skipping (already loaded): 2026-03-18
# 2026-04-13 16:38:24,123 INFO:   ✓ Skipping (already loaded): 2026-03-19
# 2026-04-13 16:38:24,130 INFO:   ✓ Skipping (already loaded): 2026-03-20
# 2026-04-13 16:38:24,137 INFO:   ✓ Skipping (already loaded): 2026-03-23
# 2026-04-13 16:38:24,147 INFO:   ✓ Skipping (already loaded): 2026-03-24
# 2026-04-13 16:38:24,153 INFO:   ✓ Skipping (already loaded): 2026-03-25
# 2026-04-13 16:38:24,158 INFO:   ✓ Skipping (already loaded): 2026-03-26
# 2026-04-13 16:38:24,163 INFO:   ✓ Skipping (already loaded): 2026-03-27
SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260331.csv
# 2026-04-13 16:38:33,252 INFO:
#    Total files ready for processing: 150
# 2026-04-13 16:38:33,254 INFO:
# ============================================================
# 2026-04-13 16:38:33,255 INFO: STEP 2 & 3: TRANSFORM + LOAD  [Marex]
# 2026-04-13 16:38:33,255 INFO: ============================================================
# 2026-04-13 16:38:33,256 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260216.csv
# 2026-04-13 16:38:33,268 WARNING:   No records remain after filtering: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260216.csv
# 2026-04-13 16:38:33,269 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260216.csv
# 2026-04-13 16:38:33,281 WARNING:   No records remain after filtering: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260216.csv
# 2026-04-13 16:38:33,281 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260216.csv
# 2026-04-13 16:38:33,323 INFO:   Filtered to 9028 records
# 2026-04-13 16:38:33,453 INFO:   Transform complete: 134 records ready
# 2026-04-13 16:38:33,480 INFO:   ✓ Loaded 134 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260216.csv
# 2026-04-13 16:38:33,481 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260216.csv
# 2026-04-13 16:38:33,498 INFO:   Filtered to 522 records
# 2026-04-13 16:38:33,514 INFO:   Transform complete: 34 records ready
# 2026-04-13 16:38:33,538 INFO:   ✓ Loaded 34 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260216.csv
# 2026-04-13 16:38:33,539 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260216.csv
# 2026-04-13 16:38:33,552 INFO:   Filtered to 44 records
# 2026-04-13 16:38:33,562 INFO:   Transform complete: 4 records ready
# 2026-04-13 16:38:33,578 INFO:   ✓ Loaded 4 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260216.csv
# 2026-04-13 16:38:33,578 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260218.csv
# 2026-04-13 16:38:33,600 INFO:   Filtered to 3743 records
# 2026-04-13 16:38:33,661 INFO:   Transform complete: 118 records ready
# 2026-04-13 16:38:33,686 INFO:   ✓ Loaded 118 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260218.csv
# 2026-04-13 16:38:33,687 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260218.csv
# 2026-04-13 16:38:33,766 INFO:   Filtered to 18567 records
# 2026-04-13 16:38:34,035 INFO:   Transform complete: 238 records ready
# 2026-04-13 16:38:34,069 INFO:   ✓ Loaded 238 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260218.csv
# 2026-04-13 16:38:34,070 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260218.csv
# 2026-04-13 16:38:34,115 INFO:   Filtered to 10310 records
# 2026-04-13 16:38:34,272 INFO:   Transform complete: 158 records ready
# 2026-04-13 16:38:34,309 INFO:   ✓ Loaded 158 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260218.csv
# 2026-04-13 16:38:34,310 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260218.csv
# 2026-04-13 16:38:34,335 INFO:   Filtered to 3415 records
# 2026-04-13 16:38:34,392 INFO:   Transform complete: 92 records ready
# 2026-04-13 16:38:34,421 INFO:   ✓ Loaded 92 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260218.csv
# 2026-04-13 16:38:34,421 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260218.csv
# 2026-04-13 16:38:34,431 INFO:   Filtered to 29 records
# 2026-04-13 16:38:34,441 INFO:   Transform complete: 3 records ready
# 2026-04-13 16:38:34,461 INFO:   ✓ Loaded 3 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260218.csv
# 2026-04-13 16:38:34,462 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260219.csv
# 2026-04-13 16:38:34,491 INFO:   Filtered to 5531 records
# 2026-04-13 16:38:34,581 INFO:   Transform complete: 108 records ready
# 2026-04-13 16:38:34,602 INFO:   ✓ Loaded 108 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260219.csv
# 2026-04-13 16:38:34,603 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20
INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260223.csv
# 2026-04-13 16:38:37,795 INFO:   Filtered to 4182 records
# 2026-04-13 16:38:37,861 INFO:   Transform complete: 106 records ready
# 2026-04-13 16:38:37,894 INFO:   ✓ Loaded 106 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260223.csv
# 2026-04-13 16:38:37,895 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260223.csv
# 2026-04-13 16:38:37,907 INFO:   Filtered to 201 records
# 2026-04-13 16:38:37,919 INFO:   Transform complete: 8 records ready
# 2026-04-13 16:38:37,940 INFO:   ✓ Loaded 8 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260223.csv
# 2026-04-13 16:38:37,941 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260225.csv
# 2026-04-13 16:38:37,974 INFO:   Filtered to 7614 records
# 2026-04-13 16:38:38,087 INFO:   Transform complete: 106 records ready
# 2026-04-13 16:38:38,132 INFO:   ✓ Loaded 106 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260225.csv
# 2026-04-13 16:38:38,133 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260225.csv
# 2026-04-13 16:38:38,208 INFO:   Filtered to 20085 records
# 2026-04-13 16:38:38,482 INFO:   Transform complete: 235 records ready
# 2026-04-13 16:38:38,542 INFO:   ✓ Loaded 235 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260225.csv
# 2026-04-13 16:38:38,543 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260225.csv
# 2026-04-13 16:38:38,591 INFO:   Filtered to 11455 records
# 2026-04-13 16:38:38,761 INFO:   Transform complete: 174 records ready
# 2026-04-13 16:38:38,866 INFO:   ✓ Loaded 174 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260225.csv
# 2026-04-13 16:38:38,867 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260225.csv
# 2026-04-13 16:38:38,897 INFO:   Filtered to 4219 records
# 2026-04-13 16:38:38,964 INFO:   Transform complete: 105 records ready
# 2026-04-13 16:38:39,004 INFO:   ✓ Loaded 105 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260225.csv
# 2026-04-13 16:38:39,005 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260225.csv
# 2026-04-13 16:38:39,018 INFO:   Filtered to 76 records
# 2026-04-13 16:38:39,028 INFO:   Transform complete: 8 records ready
# 2026-04-13 16:38:39,049 INFO:   ✓ Loaded 8 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260225.csv
# 2026-04-13 16:38:39,050 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260226.csv
# 2026-04-13 16:38:39,086 INFO:   Filtered to 8506 records
# 2026-04-13 16:38:39,211 INFO:   Transform complete: 106 records ready
# ...
# 2026-04-13 16:38:58,978 INFO:   Transform complete: 128 records ready
# 2026-04-13 16:38:59,008 INFO:   ✓ Loaded 128 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260319.csv
# 2026-04-13 16:38:59,009 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260319.csv
# 2026-04-13 16:38:59,025 INFO:   Filtered to 974 records
# 2026-04-13 16:38:59,047 INFO:   Transform complete: 13 records ready
# 2026-04-13 16:38:59,062 INFO:   ✓ Loaded 13 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260319.csv
# 2026-04-13 16:38:59,063 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260320.csv
# 2026-04-13 16:38:59,094 INFO:   Filtered to 7618 records
# 2026-04-13 16:38:59,203 INFO:   Transform complete: 97 records ready
# 2026-04-13 16:38:59,224 INFO:   ✓ Loaded 97 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260320.csv
# 2026-04-13 16:38:59,225 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260320.csv
# 2026-04-13 16:38:59,300 INFO:   Filtered to 22382 records
# 2026-04-13 16:38:59,606 INFO:   Transform complete: 217 records ready
# 2026-04-13 16:38:59,643 INFO:   ✓ Loaded 217 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260320.csv
# 2026-04-13 16:38:59,644 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260320.csv
# 2026-04-13 16:38:59,726 INFO:   Filtered to 22833 records
# 2026-04-13 16:39:00,031 INFO:   Transform complete: 206 records ready
# 2026-04-13 16:39:00,059 INFO:   ✓ Loaded 206 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260320.csv
# 2026-04-13 16:39:00,060 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260320.csv
# 2026-04-13 16:39:00,091 INFO:   Filtered to 4960 records
# 2026-04-13 16:39:00,168 INFO:   Transform complete: 85 records ready
# 2026-04-13 16:39:00,189 INFO:   ✓ Loaded 85 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260320.csv
# 2026-04-13 16:39:00,190 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260320.csv
# 2026-04-13 16:39:00,200 INFO:   Filtered to 123 records
# 2026-04-13 16:39:00,211 INFO:   Transform complete: 8 records ready
# 2026-04-13 16:39:00,225 INFO:   ✓ Loaded 8 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260320.csv
# 2026-04-13 16:39:00,225 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260323.csv
# 2026-04-13 16:39:00,263 INFO:   Filtered to 10332 records
# 2026-04-13 16:39:00,408 INFO:   Transform complete: 101 records ready
# 2026-04-13 16:39:00,428 INFO:   ✓ Loaded 101 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260323.csv
# 2026-04-13 16:39:00,429 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260323.csv
# 2026-04-13 16:39:00,520 INFO:   Filtered to 28786 records
# 2026-04-13 16:39:00,921 INFO:   Transform complete: 222 records ready
# 2026-04-13 16:39:00,950 INFO:   ✓ Loaded 222 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260323.csv
# 2026-04-13 16:39:00,951 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260323.csv
# 2026-04-13 16:39:01,080 INFO:   Filtered to 40919 records
# 2026-04-13 16:39:01,635 INFO:   Transform complete: 204 records ready
# 2026-04-13 16:39:01,667 INFO:   ✓ Loaded 204 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260323.csv
# 2026-04-13 16:39:01,668 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260323.csv
# 2026-04-13 16:39:01,719 INFO:   Filtered to 8622 records
# 2026-04-13 16:39:01,849 INFO:   Transform complete: 92 records ready
# 2026-04-13 16:39:01,873 INFO:   ✓ Loaded 92 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260323.csv
# 2026-04-13 16:39:01,874 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260323.csv
# 2026-04-13 16:39:01,886 INFO:   Filtered to 245 records
# 2026-04-13 16:39:01,900 INFO:   Transform complete: 7 records ready
# 2026-04-13 16:39:01,916 INFO:   ✓ Loaded 7 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260323.csv
# 2026-04-13 16:39:01,916 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260324.csv
# 2026-04-13 16:39:01,952 INFO:   Filtered to 6038 records
# 2026-04-13 16:39:02,048 INFO:   Transform complete: 95 records ready
# 2026-04-13 16:39:02,068 INFO:   ✓ Loaded 95 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260324.csv
# 2026-04-13 16:39:02,069 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260324.csv
# 2026-04-13 16:39:02,145 INFO:   Filtered to 22648 records
# 2026-04-13 16:39:02,453 INFO:   Transform complete: 210 records ready
# 2026-04-13 16:39:02,481 INFO:   ✓ Loaded 210 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260324.csv
# 2026-04-13 16:39:02,481 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260324.csv
# 2026-04-13 16:39:02,575 INFO:   Filtered to 27252 records
# 2026-04-13 16:39:02,943 INFO:   Transform complete: 200 records ready
# 2026-04-13 16:39:02,968 INFO:   ✓ Loaded 200 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260324.csv
# 2026-04-13 16:39:02,970 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260324.csv
# 2026-04-13 16:39:03,011 INFO:   Filtered to 5757 records
# 2026-04-13 16:39:03,094 INFO:   Transform complete: 86 records ready
# 2026-04-13 16:39:03,117 INFO:   ✓ Loaded 86 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260324.csv
# 2026-04-13 16:39:03,118 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260324.csv
# 2026-04-13 16:39:03,131 INFO:   Filtered to 377 records
# 2026-04-13 16:39:03,145 INFO:   Transform complete: 13 records ready
# 2026-04-13 16:39:03,163 INFO:   ✓ Loaded 13 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260324.csv
# 2026-04-13 16:39:03,164 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260325.csv
# 2026-04-13 16:39:03,192 INFO:   Filtered to 3978 records
# 2026-04-13 16:39:03,325 INFO:   Transform complete: 95 records ready
# 2026-04-13 16:39:03,344 INFO:   ✓ Loaded 95 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260325.csv
# 2026-04-13 16:39:03,345 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260325.csv
# 2026-04-13 16:39:03,398 INFO:   Filtered to 13411 records
# 2026-04-13 16:39:03,579 INFO:   Transform complete: 199 records ready
# 2026-04-13 16:39:03,616 INFO:   ✓ Loaded 199 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260325.csv
# 2026-04-13 16:39:03,616 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260325.csv
# 2026-04-13 16:39:03,708 INFO:   Filtered to 26414 records
# 2026-04-13 16:39:04,069 INFO:   Transform complete: 200 records ready
# 2026-04-13 16:39:04,108 INFO:   ✓ Loaded 200 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260325.csv
# 2026-04-13 16:39:04,108 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260325.csv
# 2026-04-13 16:39:04,147 INFO:   Filtered to 6430 records
# 2026-04-13 16:39:04,239 INFO:   Transform complete: 94 records ready
# 2026-04-13 16:39:04,267 INFO:   ✓ Loaded 94 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260325.csv
# 2026-04-13 16:39:04,268 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260325.csv
# 2026-04-13 16:39:04,280 INFO:   Filtered to 287 records
# 2026-04-13 16:39:04,293 INFO:   Transform complete: 10 records ready
# 2026-04-13 16:39:04,314 INFO:   ✓ Loaded 10 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260325.csv
# 2026-04-13 16:39:04,315 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260326.csv
# 2026-04-13 16:39:04,342 INFO:   Filtered to 4605 records
# 2026-04-13 16:39:04,412 INFO:   Transform complete: 88 records ready
# 2026-04-13 16:39:04,436 INFO:   ✓ Loaded 88 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260326.csv
# 2026-04-13 16:39:04,437 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260326.csv
# 2026-04-13 16:39:04,493 INFO:   Filtered to 13975 records
# 2026-04-13 16:39:04,688 INFO:   Transform complete: 209 records ready
# 2026-04-13 16:39:04,720 INFO:   ✓ Loaded 209 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260326.csv
# 2026-04-13 16:39:04,720 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260326.csv
# 2026-04-13 16:39:04,788 INFO:   Filtered to 18548 records
# 2026-04-13 16:39:05,051 INFO:   Transform complete: 199 records ready
# 2026-04-13 16:39:05,078 INFO:   ✓ Loaded 199 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260326.csv
# 2026-04-13 16:39:05,079 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260326.csv
# 2026-04-13 16:39:05,109 INFO:   Filtered to 6230 records
# 2026-04-13 16:39:05,203 INFO:   Transform complete: 96 records ready
# 2026-04-13 16:39:05,223 INFO:   ✓ Loaded 96 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260326.csv
# 2026-04-13 16:39:05,224 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260326.csv
# 2026-04-13 16:39:05,235 INFO:   Filtered to 277 records
# 2026-04-13 16:39:05,249 INFO:   Transform complete: 10 records ready
# 2026-04-13 16:39:05,265 INFO:   ✓ Loaded 10 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260326.csv
# 2026-04-13 16:39:05,266 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260327.csv
# 2026-04-13 16:39:05,291 INFO:   Filtered to 3578 records
# 2026-04-13 16:39:05,351 INFO:   Transform complete: 99 records ready
# 2026-04-13 16:39:05,376 INFO:   ✓ Loaded 99 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260327.csv
# 2026-04-13 16:39:05,377 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260327.csv
# 2026-04-13 16:39:05,440 INFO:   Filtered to 16836 records
# 2026-04-13 16:39:05,770 INFO:   Transform complete: 211 records ready
# 2026-04-13 16:39:05,794 INFO:   ✓ Loaded 211 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260327.csv
# 2026-04-13 16:39:05,795 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260327.csv
# 2026-04-13 16:39:05,867 INFO:   Filtered to 19869 records
# 2026-04-13 16:39:06,265 INFO:   Transform complete: 183 records ready
# 2026-04-13 16:39:06,294 INFO:   ✓ Loaded 183 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260327.csv
# 2026-04-13 16:39:06,295 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260327.csv
# 2026-04-13 16:39:06,334 INFO:   Filtered to 4983 records
# 2026-04-13 16:39:06,426 INFO:   Transform complete: 83 records ready
# 2026-04-13 16:39:06,458 INFO:   ✓ Loaded 83 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260327.csv
# 2026-04-13 16:39:06,459 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260327.csv
# 2026-04-13 16:39:06,475 INFO:   Filtered to 167 records
# 2026-04-13 16:39:06,486 INFO:   Transform complete: 6 records ready
# 2026-04-13 16:39:06,502 INFO:   ✓ Loaded 6 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260327.csv
# 2026-04-13 16:39:06,503 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260330.csv
# 2026-04-13 16:39:06,528 INFO:   Filtered to 4643 records
# 2026-04-13 16:39:06,628 INFO:   Transform complete: 93 records ready
# 2026-04-13 16:39:06,658 INFO:   ✓ Loaded 93 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260330.csv
# 2026-04-13 16:39:06,659 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260330.csv
# 2026-04-13 16:39:06,724 INFO:   Filtered to 12907 records
# 2026-04-13 16:39:06,920 INFO:   Transform complete: 200 records ready
# 2026-04-13 16:39:06,964 INFO:   ✓ Loaded 200 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260330.csv
# 2026-04-13 16:39:06,966 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260330.csv
# 2026-04-13 16:39:07,027 INFO:   Filtered to 12033 records
# 2026-04-13 16:39:07,279 INFO:   Transform complete: 186 records ready
# 2026-04-13 16:39:07,310 INFO:   ✓ Loaded 186 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260330.csv
# 2026-04-13 16:39:07,310 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260330.csv
# 2026-04-13 16:39:07,351 INFO:   Filtered to 4521 records
# 2026-04-13 16:39:07,419 INFO:   Transform complete: 81 records ready
# 2026-04-13 16:39:07,444 INFO:   ✓ Loaded 81 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260330.csv
# 2026-04-13 16:39:07,445 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260330.csv
# 2026-04-13 16:39:07,459 INFO:   Filtered to 397 records
# 2026-04-13 16:39:07,473 INFO:   Transform complete: 6 records ready
# 2026-04-13 16:39:07,490 INFO:   ✓ Loaded 6 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260330.csv
# 2026-04-13 16:39:07,491 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260331.csv
# 2026-04-13 16:39:07,521 INFO:   Filtered to 5386 records
# 2026-04-13 16:39:07,631 INFO:   Transform complete: 93 records ready
# 2026-04-13 16:39:07,659 INFO:   ✓ Loaded 93 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CBT_20260331.csv
# 2026-04-13 16:39:07,660 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260331.csv
# 2026-04-13 16:39:07,757 INFO:   Filtered to 15043 records
# 2026-04-13 16:39:08,054 INFO:   Transform complete: 209 records ready
# 2026-04-13 16:39:08,084 INFO:   ✓ Loaded 209 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_CME_20260331.csv
# 2026-04-13 16:39:08,085 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260331.csv
# 2026-04-13 16:39:08,169 INFO:   Filtered to 17750 records
# 2026-04-13 16:39:08,492 INFO:   Transform complete: 201 records ready
# 2026-04-13 16:39:08,513 INFO:   ✓ Loaded 201 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_IFLL_20260331.csv
# 2026-04-13 16:39:08,514 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260331.csv
# 2026-04-13 16:39:08,559 INFO:   Filtered to 7378 records
# 2026-04-13 16:39:08,724 INFO:   Transform complete: 91 records ready
# 2026-04-13 16:39:08,752 INFO:   ✓ Loaded 91 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_OTHERS_20260331.csv
# 2026-04-13 16:39:08,753 INFO:
#   Processing: SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260331.csv
# 2026-04-13 16:39:08,766 INFO:   Filtered to 314 records
# 2026-04-13 16:39:08,782 INFO:   Transform complete: 6 records ready
# 2026-04-13 16:39:08,797 INFO:   ✓ Loaded 6 records from SYMMETRY_FINANCIALS_LIMITED_CLEARISK_CoreTrades_MFLA_LME.20260331.csv
# 2026-04-13 16:39:08,798 INFO:
# ============================================================
# 2026-04-13 16:39:08,798 INFO: PIPELINE COMPLETE  [Marex]
# 2026-04-13 16:39:08,799 INFO: ============================================================
# 2026-04-13 16:39:08,799 INFO:   Files downloaded : 150
# 2026-04-13 16:39:08,800 INFO:   Files loaded     : 148
# 2026-04-13 16:39:08,800 INFO:   Files skipped    : 0
# 2026-04-13 16:39:08,801 INFO:   Files failed     : 2
# 2026-04-13 16:39:08,801 INFO: ============================================================
# {'downloaded': 150, 'loaded': 148, 'skipped': 0, 'failed': 2}

# %%
from cores.pipeline import run_pipeline
from exchanges.marexus_new import EXCHANGE_CONFIG, step_transform, step_load

run_pipeline(
    config=EXCHANGE_CONFIG,
    transform_func=step_transform,
    load_func=step_load,
    credentials_file="aws_credentials.json",
    start_date_str="20260303",
    end_date_str="20260331"
)
# Out:
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260303.csv
#    -> S3: Downloading reference SYM/2026/03/03/TRD_SYM_20260303.csv...
# ✅ Transform complete — Aggregated 234 raw rows into 2 unique records.
#    Loading 2 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260304.csv
#    -> S3: Downloading reference SYM/2026/03/04/TRD_SYM_20260304.csv...
# ✅ Transform complete — Aggregated 194 raw rows into 5 unique records.
#    Loading 5 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260305.csv
#    -> S3: Downloading reference SYM/2026/03/05/TRD_SYM_20260305.csv...
# ✅ Transform complete — Aggregated 186 raw rows into 2 unique records.
#    Loading 2 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260306.csv
#    -> S3: Downloading reference SYM/2026/03/06/TRD_SYM_20260306.csv...
#
# ‼️ DEBUG: Found the NFLX duplicates in DataFrame:
#      Trade_date        CtrCode   ClientID ProductType  Quantity  TotalUSD
# 0    2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         3   1125.56
# 1    2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         8   4203.72
# 2    2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         2     32.55
# 3    2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         2     58.55
# 4    2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         2    142.55
# 5    2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         2   7862.55
# 6    2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         5  15032.61
# 7    2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        19  20402.86
# 8    2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         5   4812.61
# 9    2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         3   2062.58
# 10   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         2    267.55
# 11   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        35   3254.40
# 12   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        35   4954.35
# 13   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        54   3361.66
# 14   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        40   3434.92
# 15   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        73   3374.28
# 16   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        25   1833.07
# 17   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         4    212.59
# 18   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         3    117.56
# 19   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         2    732.55
# 20   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         5   1492.61
# 21   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        82  13880.38
# 22   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        41   3289.96
# 23   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        56   3641.85
# 24   2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         
2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         2   1424.55
# 150  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         2    207.55
# 151  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         3    307.58
# 152  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        10   2152.73
# 153  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        12   2377.82
# 154  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        19   3178.03
# 155  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        54   9746.62
# 156  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        36   5819.51
# 157  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         5   6802.61
# 158  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        18  19992.99
# 159  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        18  18902.91
# 160  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         2   3502.55
# 161  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        40   7094.92
# 162  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        25   8688.07
# 163  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        35   6164.30
# 164  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        11   6322.80
# 165  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        28   8643.40
# 166  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        18  23587.95
# 167  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        17  16142.86
# 168  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1    102.52
# 169  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1    112.52
# 170  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1    102.52
# 171  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         4    407.59
# 172  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         8   1922.68
# 173  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         4    942.59
# 174  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        15   2402.84
# 175  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        22   3592.96
# 176  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        88  15545.46
# 177  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        27   4928.39
# 178  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        13   1742.85
# 179  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        11   7682.73
# 180  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         9  15647.68
# 181  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        12  20742.74
# 182  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        11  14922.71
# 183  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         6   7502.64
# 184  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1    107.52
# 185  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         4    977.59
# 186  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1    102.52
# 187  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         5    507.61
# 188  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         9   1377.73
# 189  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        21   3192.88
# 190  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         3    312.56
# 191  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         2    207.55
# 192  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1    107.52
# 193  2026-03-06  OPT-GOOG-XNAS  SYMMSUB11      Option         3    339.56
# 194  2026-03-06  OPT-META-XNAS  SYMMSUB11      Option         3    804.56
# 195  2026-03-06  OPT-META-XNAS  SYMMSUB11      Option        16   3221.91
# 196  2026-03-06  OPT-NFLX-XNAS  SYMMSUB11      Option        22    664.10
# 197  2026-03-06  OPT-TSLA-XNAS  SYMMSUB11      Option         7   1203.65
# 198  2026-03-06  OPT-TSLA-XNAS  SYMMSUB11      Option         4    443.59
# 199  2026-03-06  OPT-NFLX-XNAS  SYMMSUB11      Option         2     84.55
# 200  2026-03-06  OPT-GOOG-XNAS  SYMMSUB11      Option        22   1191.00
# 201  2026-03-06  OPT-META-XNAS  SYMMSUB11      Option         4    656.59
# 202  2026-03-06  OPT-META-XNAS  SYMMSUB11      Option         2    485.55
# 203  2026-03-06  OPT-TSLA-XNAS  SYMMSUB11      Option        14   1730.84
# 204  2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option        10     54.73
# 205  2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         7     23.66
# 206  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        10   1307.73
# 207  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        15   2802.89
# 208  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         9    747.73
# 209  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         5    302.61
# 210  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1     22.52
# 211  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1     22.52
# 212  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         3     42.56
# 213  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         5     67.61
# 214  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         9     52.75
# 215  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         2     22.55
# 216  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         7    592.69
# 217  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         2     42.55
# 218  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         6     72.66
# 219  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1     22.52
# 220  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         3    417.56
# 221  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1     47.52
# 222  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1   3092.52
# 223  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1     57.52
# 224  2026-03-06  OPT-GOOG-XNAS  SYMMSUB11      Option        20    292.96
# 225  2026-03-06  OPT-META-XNAS  SYMMSUB11      Option         1     37.52
# 226  2026-03-06  OPT-META-XNAS  SYMMSUB11      Option         5    172.61
# 227  2026-03-06  OPT-TSLA-XNAS  SYMMSUB11      Option         1     42.52
# 228  2026-03-06  OPT-META-XNAS  SYMMSUB11      Option        10    347.73
# 229  2026-03-06  OPT-TSLA-XNAS  SYMMSUB11      Option         4     72.59
# 230  2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         5     37.61
# 231  2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         2     16.55
# 232  2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         8     58.68
# 233  2026-03-06    OPT-SPXW-SG  SYMMSUB10      Option         2     16.55
# 234  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1     12.52
# 235  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option        10    102.73
# 236  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         3     52.58
# 237  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1    117.52
# 238  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         3    467.57
# 239  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         4    417.59
# 240  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1     22.52
# 241  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1    137.52
# 242  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         6    557.64
# 243  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         4    882.59
# 244  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1     12.52
# 245  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         6    107.64
# 246  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         2     22.55
# 247  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         3     37.58
# 248  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         3   1102.58
# 249  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         7   1482.67
# 250  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         4    477.59
# 251  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         1    142.52
# 252  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         2     22.55
# 253  2026-03-06    OPT-SPXW-SG  SYMMSUB11      Option         5     52.61
# 254  2026-03-06  OPT-META-XNAS  SYMMSUB11      Option         3    152.57
# 255  2026-03-06  OPT-META-XNAS  SYMMSUB11      Option         2    107.55
# 256  2026-03-06  OPT-NFLX-XNAS  SYMMSUB11      Option        17     92.82
# 257  2026-03-06  OPT-TSLA-XNAS  SYMMSUB11      Option         6    202.62
# 258  2026-03-06  OPT-NFLX-XNAS  SYMMSUB11      Option         2     12.55
# 259  2026-03-06  OPT-GOOG-XNAS  SYMMSUB11      Option        12    137.78
# 260  2026-03-06  OPT-META-XNAS  SYMMSUB11      Option         3    107.57
# 261  2026-03-06  OPT-TSLA-XNAS  SYMMSUB11      Option         7    202.65
# ✅ Transform complete — Aggregated 262 raw rows into 6 unique records.
#    Loading 6 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260309.csv
#    -> S3: Downloading reference SYM/2026/03/09/TRD_SYM_20260309.csv...
# c:\Users\Axxela\Desktop\CART\exchanges\marexus_new.py:210: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade_date'] = pd.to_datetime(df['Trade Date'], errors='coerce').dt.date
# c:\Users\Axxela\Desktop\CART\exchanges\marexus_new.py:243: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade_date'] = pd.to_datetime(df['Trade Date'], errors='coerce').dt.date
# ✅ Transform complete — Aggregated 296 raw rows into 8 unique records.
#    Loading 8 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260310.csv
#    -> S3: Downloading reference SYM/2026/03/10/TRD_SYM_20260310.csv...
# c:\Users\Axxela\Desktop\CART\exchanges\marexus_new.py:210: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade_date'] = pd.to_datetime(df['Trade Date'], errors='coerce').dt.date
# c:\Users\Axxela\Desktop\CART\exchanges\marexus_new.py:243: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade_date'] = pd.to_datetime(df['Trade Date'], errors='coerce').dt.date
# ‼️ DEBUG: Found the NFLX duplicates in DataFrame:
#      Trade_date        CtrCode   ClientID ProductType  Quantity  TotalUSD
# 0    2026-03-06  EQU-NFLX-XNAS  SYMMSUB11      Equity       400  39605.00
# 1    2026-03-06  EQU-NFLX-XNAS  SYMMSUB11      Equity       400  39605.00
# 2    2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    942.52
# 3    2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    822.52
# 4    2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2    742.55
# 5    2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option        10   7462.73
# 6    2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    522.52
# 7    2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         3   2112.56
# 8    2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         8   3237.72
# 9    2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    912.52
# 10   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2   1702.55
# 11   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    672.52
# 12   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option        14   9897.88
# 13   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2   4772.55
# 14   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6  14862.66
# 15   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        12  20582.78
# 16   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         4   4652.59
# 17   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        25  20453.07
# 18   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        30  14143.59
# 19   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        44  12550.25
# 20   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option       114  21208.90
# 21   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2     37.55
# 22   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    162.52
# 23   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        10  11727.73
# 24   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        54  15916.66
# 25   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        46   4510.44
# 26   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1   2682.52
# 27   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         4   9162.59
# 28   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   6472.62
# 29   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         7   6887.65
# 30   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        13  11732.83
# 31   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        32  14293.85
# 32   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        84  18270.25
# 33   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        76  17654.26
# 34   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        13    512.79
# 35   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         4    142.59
# 36   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    152.52
# 37   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         4   3152.59
# 38   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         7   3722.67
# 39   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    562.52
# 40   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    122.52
# 41   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2    492.55
# 42   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2    942.55
# 43   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2   1192.55
# 44   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         7   3472.63
# 45   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         5   3062.61
# 46   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         3   1272.56
# 47   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2    342.55
# 48   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2   1047.55
# 49   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2    237.55
# 50   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         5    342.61
# 51   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        41   3344.90
# 52   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        26   2108.16
# 53   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        47   7035.57
# 54   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        47   6551.00
# 55   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        31  10443.68
# 56   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   4392.66
# 57   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        17  15122.86
# 58   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        14  14642.76
# 59   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6    802.62
# 60   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    217.52
# 61   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2    422.55
# 62   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         5    352.61
# 63   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        12    382.82
# 64   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        62   5142.46
# 65   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        19   8442.93
# 66   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        10   7642.73
# 67   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   5772.66
# 68   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        37  15424.67
# 69   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        15  13457.84
# 70   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        17  19422.84
# 71   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        10  11542.73
# 72   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2   2142.55
# 73   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        30   6323.79
# 74   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        22   5833.00
# 75   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    252.52
# 76   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         5    482.61
# 77   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        12    772.82
# 78   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         8    922.68
# 79   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   1307.64
# 80   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        36   4109.51
# 81   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    782.52
# 82   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    582.52
# 83   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    502.52
# 84   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2    702.55
# 85   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option        10   4962.73
# 86   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    512.52
# 87   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         3   1257.56
# 88   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         8   3632.68
# 89   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    562.52
# 90   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2   1052.55
# 91   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    552.52
# 92   2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option        14   6252.84
# 93   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2   3022.55
# 94   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   9592.62
# 95   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        12  13542.74
# 96   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         4   3742.59
# 97   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        27  16478.45
# 98   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        32  10074.01
# 99   2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        51   8301.42
# 100  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option       125  13505.37
# 101  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2    212.55
# 102  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    572.52
# 103  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        11   9342.74
# 104  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        57  11221.76
# 105  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        58   6297.23
# 106  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1   1772.52
# 107  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         4   5802.59
# 108  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   4972.62
# 109  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         7   5832.68
# 110  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        13   7692.82
# 111  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        37  12604.53
# 112  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        96  12081.88
# 113  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        89  10320.70
# 114  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        13   1522.76
# 115  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         4    382.59
# 116  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    472.52
# 117  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         4   1912.59
# 118  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         7   3322.69
# 119  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    342.52
# 120  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    402.52
# 121  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2    622.55
# 122  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2    982.55
# 123  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2    682.55
# 124  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         7   3362.66
# 125  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         5   2392.61
# 126  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         3   1562.57
# 127  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2   1092.55
# 128  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         2   1072.55
# 129  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         3    307.58
# 130  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         5    832.61
# 131  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        45   6995.38
# 132  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        28   6573.36
# 133  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        48   7995.98
# 134  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        48   8511.02
# 135  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        32   7698.97
# 136  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   3652.62
# 137  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        17  11357.87
# 138  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        14   8952.88
# 139  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6    607.62
# 140  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         5    522.61
# 141  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2    202.55
# 142  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    102.52
# 143  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2    312.55
# 144  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   1112.64
# 145  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    107.52
# 146  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2    397.55
# 147  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        14   2872.82
# 148  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   1082.64
# 149  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        12   1982.78
# 150  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        64  11808.19
# 151  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        20   6502.96
# 152  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        11   6797.78
# 153  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   3582.66
# 154  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        47  13490.55
# 155  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        21  12273.07
# 156  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        17  14862.93
# 157  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        10   7262.73
# 158  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2   1272.55
# 159  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        33   9688.90
# 160  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        26   9578.22
# 161  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        16   3497.91
# 162  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    102.52
# 163  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         9   1432.72
# 164  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        13   2007.79
# 165  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         8   1317.72
# 166  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6    852.66
# 167  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        37   6804.41
# 168  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         3    257.57
# 169  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         5    537.61
# 170  2026-03-10    OPT-SPXW-SG   SYMMSUB9      Option         1    832.52
# 171  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2     77.55
# 172  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2     62.55
# 173  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         7    982.66
# 174  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        11   1942.71
# 175  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1     52.52
# 176  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         3     82.58
# 177  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        12   1147.82
# 178  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         5    407.61
# 179  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        12   1802.78
# 180  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        13   1892.74
# 181  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1     67.52
# 182  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         4    302.59
# 183  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2    212.55
# 184  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    107.52
# 185  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    182.52
# 186  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1     92.52
# 187  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         5     52.61
# 188  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2     22.55
# 189  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1     12.52
# 190  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2     32.55
# 191  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         5     77.61
# 192  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1     12.52
# 193  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2     42.55
# 194  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        12    182.78
# 195  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1     22.52
# 196  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         2    207.55
# 197  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    167.52
# 198  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    157.52
# 199  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        10   1867.73
# 200  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         6   1192.62
# 201  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         3    327.56
# 202  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         4    417.59
# 203  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option        16    242.87
# 204  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         4     62.59
# 205  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1     22.52
# 206  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         1    112.52
# 207  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         3     32.57
# 208  2026-03-10    OPT-SPXW-SG  SYMMSUB11      Option         5     52.61
# ✅ Transform complete — Aggregated 209 raw rows into 3 unique records.
#    Loading 3 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260311.csv
#    -> S3: Downloading reference SYM/2026/03/11/TRD_SYM_20260311.csv...
# ✅ Transform complete — Aggregated 287 raw rows into 6 unique records.
#    Loading 6 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260312.csv
#    -> S3: Downloading reference SYM/2026/03/12/TRD_SYM_20260312.csv...
# c:\Users\Axxela\Desktop\CART\exchanges\marexus_new.py:210: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade_date'] = pd.to_datetime(df['Trade Date'], errors='coerce').dt.date
# c:\Users\Axxela\Desktop\CART\exchanges\marexus_new.py:243: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade_date'] = pd.to_datetime(df['Trade Date'], errors='coerce').dt.date
# ✅ Transform complete — Aggregated 168 raw rows into 5 unique records.
#    Loading 5 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260313.csv
#    -> S3: Downloading reference SYM/2026/03/13/TRD_SYM_20260313.csv...
# c:\Users\Axxela\Desktop\CART\exchanges\marexus_new.py:210: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade_date'] = pd.to_datetime(df['Trade Date'], errors='coerce').dt.date
# c:\Users\Axxela\Desktop\CART\exchanges\marexus_new.py:243: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade_date'] = pd.to_datetime(df['Trade Date'], errors='coerce').dt.date
# ✅ Transform complete — Aggregated 417 raw rows into 13 unique records.
#    Loading 13 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260316.csv
#    -> S3: Downloading reference SYM/2026/03/16/TRD_SYM_20260316.csv...
# ✅ Transform complete — Aggregated 296 raw rows into 9 unique records.
#    Loading 9 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260317.csv
#    -> S3: Downloading reference SYM/2026/03/17/TRD_SYM_20260317.csv...
# ✅ Transform complete — Aggregated 180 raw rows into 6 unique records.
#    Loading 6 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260318.csv
#    -> S3: Downloading reference SYM/2026/03/18/TRD_SYM_20260318.csv...
# ✅ Transform complete — Aggregated 91 raw rows into 2 unique records.
#    Loading 2 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260319.csv
#    -> S3: Downloading reference SYM/2026/03/19/TRD_SYM_20260319.csv...
# ✅ Transform complete — Aggregated 146 raw rows into 1 unique records.
#    Loading 1 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260320.csv
#    -> S3: Downloading reference SYM/2026/03/20/TRD_SYM_20260320.csv...
# ✅ Transform complete — Aggregated 223 raw rows into 3 unique records.
#    Loading 3 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260323.csv
#    -> S3: Downloading reference SYM/2026/03/23/TRD_SYM_20260323.csv...
# ✅ Transform complete — Aggregated 225 raw rows into 2 unique records.
#    Loading 2 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260324.csv
#    -> S3: Downloading reference SYM/2026/03/24/TRD_SYM_20260324.csv...
# ✅ Transform complete — Aggregated 223 raw rows into 3 unique records.
#    Loading 3 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260325.csv
#    -> S3: Downloading reference SYM/2026/03/25/TRD_SYM_20260325.csv...
# c:\Users\Axxela\Desktop\CART\exchanges\marexus_new.py:210: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade_date'] = pd.to_datetime(df['Trade Date'], errors='coerce').dt.date
# c:\Users\Axxela\Desktop\CART\exchanges\marexus_new.py:243: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade_date'] = pd.to_datetime(df['Trade Date'], errors='coerce').dt.date
# ✅ Transform complete — Aggregated 234 raw rows into 13 unique records.
#    Loading 13 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260326.csv
#    -> S3: Downloading reference SYM/2026/03/26/TRD_SYM_20260326.csv...
# ✅ Transform complete — Aggregated 214 raw rows into 11 unique records.
#    Loading 11 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260327.csv
#    -> S3: Downloading reference SYM/2026/03/27/TRD_SYM_20260327.csv...
# ✅ Transform complete — Aggregated 258 raw rows into 14 unique records.
#    Loading 14 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260330.csv
#    -> S3: Downloading reference SYM/2026/03/30/TRD_SYM_20260330.csv...
# ✅ Transform complete — Aggregated 359 raw rows into 16 unique records.
#    Loading 16 aggregated rows into maexus_trades_new...
#
# 🚀 TRANSFORM TRIGGERED for: Marex Trades and Fees_20260331.csv
#    -> S3: Downloading reference SYM/2026/03/31/TRD_SYM_20260331.csv...
# ✅ Transform complete — Aggregated 384 raw rows into 17 unique records.
#    Loading 17 aggregated rows into maexus_trades_new...
# {'downloaded': 21, 'loaded': 21, 'skipped': 0, 'failed': 0}

# %%
import boto3
from cores.utils import load_credentials

key, sec = load_credentials("aws_credentials.json")
s3 = boto3.client("s3", aws_access_key_id=key, aws_secret_access_key=sec)

# Testing the 'Mixed' path
prefix = "MarexUS/2026/" 
response = s3.list_objects_v2(Bucket="axxela-s3-pub-ds1-mumbai", Prefix=prefix, Delimiter='/')
prefixes = [p['Prefix'] for p in response.get('CommonPrefixes', [])]

if prefixes:
    print(f"✅ SUCCESS! Found subfolders: {prefixes}")
else:
    print("❌ Still failing. Check if 2026 also has NO space.")
# Out:
# ✅ SUCCESS! Found subfolders: ['MarexUS/2026/03/', 'MarexUS/2026/04/']
